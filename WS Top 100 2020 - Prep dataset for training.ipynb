# %% [markdown]
# # Intro
# Prepare the *Wine Spectator* Top 100 review set for training a text classifier model.
# Reference: [Dataset Splitting Best Practices in Python](https://www.kdnuggets.com/2020/05/dataset-splitting-best-practices-python.html)

# %% [markdown]
# # Load the *Wine Spectator* Top 100 dataset

# %% [markdown]
# ## File setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd

# import libraries for file navigation
import os
import shutil
import glob
from pandas_ods_reader import read_ods

# import ML libraries
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load dataframe and reformat

# %%
# Note: save CSV files in UTF-8 format to preserve special characters.
df_Wine = pd.read_csv('./CSV_Wines.csv')

# %%
# CSV of wines is retaining a blank row at the end of the dataset. Remove the last row to prevent data type errors.

# number of rows to drop
n = 1

df_Wine.drop(df_Wine.tail(n).index, inplace = True)

# %%
df_Wine.shape
# Out:
# (3300, 18)

# %%
df_Wine.dtypes
# Out:
# Review_Year           float64
# Rank                   object
# Vintage                object
# Score                 float64
# Price                  object
# Winemaker              object
# Wine                   object
# Wine_Style             object
# Grape_Blend            object
# Blend_List             object
# Geography              object
# Cases_Made            float64
# Cases_Imported        float64
# Reviewer               object
# Drink_now             float64
# Best_Drink_from       float64
# Best_Drink_Through    float64
# Review                 object
# dtype: object

# %%
# limit dataset to text and classifier dimensions
df_Wine = df_Wine[['Wine_Style', 'Review']]
df_Wine.head()
# Out:
#   Wine_Style                                             Review
# 0        Red  Maturing well, this round red is a lovely exam...
# 1        Red  Powerful and structured, with minerally richne...
# 2        Red  Effusive aromas of black currant, blueberry, v...
# 3        Red  This distinctive red throws a lot of wild sage...
# 4        Red  A lush, ripe style, with açaí berry, blueberry...

# %%
# convert wine_style classifier from string to int for easier analysis.

# set up dictionary
style = {
    'Dessert & Fortified': 0,
    'Red': 1,
    'Rosé | Rosado': 2,
    'Sparkling': 3,
    'White': 4
}

# apply dictionary to Wine_Style column:
df_Wine.Wine_Style = [style[item] for item in df_Wine.Wine_Style]
df_Wine.head()
# Out:
#    Wine_Style                                             Review
# 0           1  Maturing well, this round red is a lovely exam...
# 1           1  Powerful and structured, with minerally richne...
# 2           1  Effusive aromas of black currant, blueberry, v...
# 3           1  This distinctive red throws a lot of wild sage...
# 4           1  A lush, ripe style, with açaí berry, blueberry...

# %% [markdown]
# # Explore dataset

# %% [markdown]
# ## Randomly shuffle instances
# Shuffle records in dataset to prevent biases. Avoids circumstance where one classifier might appear in the training dataset but not the testing dataset, or vice versa.

# %%
X, y = df_Wine.Review, df_Wine.Wine_Style
print(f'Dataset labels: {df_Wine.Wine_Style}')
# Out:
# Dataset labels: 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# 5       4
# 6       1
# 7       1
# 8       1
# 9       3
# 10      1
# 11      1
# 12      1
# 13      1
# 14      1
# 15      1
# 16      4
# 17      4
# 18      1
# 19      1
# 20      4
# 21      1
# 22      4
# 23      1
# 24      1
# 25      4
# 26      1
# 27      1
# 28      1
# 29      1
#        ..
# 3270    1
# 3271    4
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# 3276    4
# 3277    1
# 3278    1
# 3279    4
# 3280    4
# 3281    1
# 3282    1
# 3283    4
# 3284    4
# 3285    1
# 3286    1
# 3287    1
# 3288    4
# 3289    4
# 3290    4
# 3291    1
# 3292    1
# 3293    4
# 3294    4
# 3295    4
# 3296    1
# 3297    1
# 3298    1
# 3299    3
# Name: Wine_Style, Length: 3300, dtype: int64

# %%
# Split the dataset and shuffle the instances
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size = .75, 
                                                    random_state = 42)

print(f'Train labels:\n{y_train}')
print(f'Test labels:\n{y_test}')
# Out:
# Train labels:
# 650     1
# 227     1
# 365     1
# 3140    1
# 862     4
# 276     1
# 2196    1
# 1613    4
# 2216    1
# 1204    1
# 2415    4
# 407     1
# 2526    4
# 2322    1
# 2793    4
# 3115    1
# 847     4
# 2645    4
# 3225    1
# 844     1
# 7       1
# 1192    4
# 1477    1
# 1061    4
# 415     0
# 1159    1
# 990     1
# 1953    1
# 1018    1
# 199     1
#        ..
# 747     1
# 2300    0
# 21      1
# 459     4
# 1184    1
# 2324    1
# 955     1
# 1215    1
# 2433    1
# 2853    4
# 1515    3
# 2391    1
# 769     1
# 1685    1
# 130     4
# 2919    1
# 3171    1
# 2135    3
# 1482    1
# 330     4
# 1238    1
# 466     1
# 2169    1
# 1638    1
# 3092    1
# 1095    1
# 1130    1
# 1294    1
# 860     1
# 3174    1
# Name: Wine_Style, Length: 2475, dtype: int64
# Test labels:
# 52      1
# 679     1
# 1253    4
# 2130    1
# 203     1
# 2451    1
# 2073    1
# 1488    1
# 1665    4
# 485     1
# 1511    4
# 511     1
# 1703    1
# 734     1
# 70      1
# 1812    1
# 2213    4
# 2780    1
# 2857    1
# 1233    1
# 2987    4
# 1411    1
# 2004    1
# 1178    4
# 1525    1
# 1590    1
# 3266    1
# 864     4
# 80      4
# 2899    1
#        ..
# 1146    1
# 1951    1
# 3116    1
# 2678    1
# 2770    4
# 1710    1
# 2929    1
# 1134    1
# 2013    1
# 2460    1
# 219     1
# 367     1
# 2408    1
# 549     1
# 2507    4
# 2356    4
# 3120    1
# 351     1
# 2691    4
# 772     1
# 2185    1
# 2637    4
# 490     1
# 2954    1
# 2608    0
# 498     1
# 1987    1
# 210     1
# 1351    1
# 2834    1
# Name: Wine_Style, Length: 825, dtype: int64

# %% [markdown]
# ## Stratify classes
# Ensure even distribution of counts of the the different classifiers.

# %%
# Split the dataset and shuffle the instances
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size = .75, 
                                                    random_state = 42,
                                                    stratify = y)

print(f'Train labels:\n{y_train}')
print(f'Test labels:\n{y_test}')
# Out:
# Train labels:
# 2742    1
# 1810    1
# 2685    4
# 1550    4
# 1086    1
# 1711    4
# 2104    1
# 1612    3
# 1072    1
# 1875    1
# 971     4
# 96      1
# 2863    4
# 3258    3
# 2240    4
# 883     3
# 2267    4
# 100     1
# 2653    4
# 518     1
# 2398    4
# 1608    0
# 2257    1
# 415     0
# 1722    1
# 2232    1
# 2052    1
# 2567    1
# 3149    4
# 1534    1
#        ..
# 2404    4
# 409     1
# 1172    4
# 2647    4
# 2505    1
# 1437    1
# 821     1
# 2842    4
# 2794    3
# 2829    4
# 559     3
# 2860    1
# 1473    1
# 2155    4
# 2273    1
# 134     1
# 2235    4
# 1264    1
# 486     1
# 1252    1
# 579     4
# 2393    1
# 2719    1
# 2386    1
# 2942    1
# 3073    1
# 2790    1
# 774     4
# 726     1
# 1216    3
# Name: Wine_Style, Length: 2475, dtype: int64
# Test labels:
# 1454    1
# 89      4
# 3059    0
# 2448    1
# 2776    4
# 3253    1
# 1223    1
# 689     4
# 249     1
# 977     4
# 3228    1
# 993     4
# 1791    1
# 414     1
# 371     1
# 258     4
# 1700    1
# 3026    1
# 1000    1
# 3009    1
# 152     0
# 2394    3
# 1056    4
# 1643    4
# 1       1
# 3271    4
# 1026    4
# 853     1
# 3011    4
# 1841    4
#        ..
# 865     1
# 2041    1
# 3097    4
# 577     1
# 2503    0
# 1416    1
# 2830    1
# 39      1
# 624     1
# 996     4
# 2057    1
# 2741    1
# 1321    1
# 215     1
# 2999    3
# 126     1
# 2256    4
# 787     3
# 916     1
# 673     1
# 2220    4
# 2049    1
# 280     4
# 2874    4
# 1566    1
# 2319    1
# 2873    1
# 1336    1
# 1270    1
# 2443    1
# Name: Wine_Style, Length: 825, dtype: int64

# %%
print(f'Number of train instances by class: {np.bincount(y_train)}')
print(f'Number of test instances by class: {np.bincount(y_test)}')
# Out:
# Number of train instances by class: [  59 1718    7   67  624]
# Number of test instances by class: [ 20 573   2  22 208]

# %% [markdown]
# ## Stratify the training set into training and validation

# %%
# Split the dataset and shuffle the instances
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, 
                                                    train_size = .5, 
                                                    random_state = 42,
                                                    stratify = y_test)

print(f'Train labels:\n{y_test}')
print(f'Test labels:\n{y_val}')
# Out:
# Train labels:
# 1464    1
# 1185    1
# 2953    1
# 1215    1
# 3026    1
# 580     1
# 1233    1
# 952     1
# 3273    1
# 1223    1
# 926     1
# 568     1
# 654     1
# 1547    1
# 92      1
# 1935    1
# 69      4
# 1597    1
# 680     1
# 2552    1
# 2851    1
# 1716    4
# 1227    1
# 2602    1
# 2041    1
# 2158    4
# 557     1
# 2265    1
# 1695    4
# 2430    1
#        ..
# 2676    1
# 2884    1
# 2628    0
# 221     1
# 1614    1
# 2483    1
# 1231    1
# 2633    1
# 315     1
# 2802    1
# 2454    4
# 79      4
# 3223    1
# 1158    1
# 2436    1
# 3011    4
# 2160    4
# 3091    4
# 2300    0
# 2641    4
# 2564    4
# 1000    1
# 970     4
# 2902    1
# 922     1
# 1964    1
# 2803    1
# 2141    4
# 2900    1
# 220     1
# Name: Wine_Style, Length: 412, dtype: int64
# Test labels:
# 2018    1
# 1066    1
# 2416    4
# 2147    4
# 170     4
# 3217    1
# 3163    1
# 1420    1
# 292     2
# 2472    4
# 2212    0
# 1291    4
# 2203    1
# 2143    1
# 494     1
# 943     1
# 1110    1
# 2665    4
# 836     4
# 1056    4
# 2937    1
# 2376    1
# 2772    1
# 2312    1
# 123     1
# 2245    1
# 1899    1
# 280     4
# 824     1
# 126     1
#        ..
# 2901    1
# 565     1
# 2522    1
# 63      1
# 2746    1
# 743     1
# 3174    1
# 904     1
# 987     1
# 978     1
# 488     4
# 1501    1
# 1392    4
# 2613    1
# 258     4
# 1075    4
# 1027    0
# 1429    4
# 1689    4
# 1210    1
# 2555    4
# 2553    1
# 1582    1
# 1010    4
# 2536    1
# 3087    4
# 1603    1
# 2411    1
# 1685    1
# 2197    4
# Name: Wine_Style, Length: 413, dtype: int64

# %%
print(f'Number of train instances by class: {np.bincount(y_train)}')
print(f'Number of test instances by class: {np.bincount(y_test)}')
print(f'Number of val instances by class: {np.bincount(y_val)}')
# Out:
# Number of train instances by class: [  59 1718    7   67  624]
# Number of test instances by class: [ 10 286   1  11 104]
# Number of val instances by class: [ 10 287   1  11 104]

# %% [markdown]
# # Set up folder structure for TensorFlow text_dataset_from_directory

# %%
# determine if folder structure exists

path_main = './review_data/'

path_train = 'train/'
path_test = 'test/'
path_val = 'val/'

path0 = '0/'
path1 = '1/'
path2 = '2/'
path3 = '3/'
path4 = '4/'

# %%
# Start with an empty set of folders, but consistent folder structure

path_mains = [path_main]
paths = [path_train, path_test, path_val]
subpaths = [path0, path1, path2, path3, path4]

for path_main in path_mains: 
    checkpath = path_main
    isDir = os.path.isdir(checkpath)
    
    # Create directories if do not already exist
    if isDir  == False:
        os.mkdir(checkpath)
        print(f'Directory {checkpath} created')
    else:
        shutil.rmtree(checkpath)
        os.mkdir(checkpath)
        print(f'Directory {checkpath} deleted and recreated')
        
    
    for path in paths:
        checkpath = path_main + path
        isDir = os.path.isdir(checkpath)
        
        # Create directories if do not already exist
        if isDir  == False:
            os.mkdir(checkpath)
            print(f'Directory {checkpath} created')
        else:
            print(f'Directory {checkpath} already exists')
            
        
                    
        for subpath in subpaths:
            checkpath = path_main + path + subpath
            isDir = os.path.isdir(checkpath)
            
            # Create directories if do not already exist
            if isDir  == False:
                os.mkdir(checkpath)
                print(f'Directory {checkpath} created')
            else:
                print(f'Directory {checkpath} already exists')
# Out:
# Directory ./review_data/ deleted and recreated
# Directory ./review_data/train/ created
# Directory ./review_data/train/0/ created
# Directory ./review_data/train/1/ created
# Directory ./review_data/train/2/ created
# Directory ./review_data/train/3/ created
# Directory ./review_data/train/4/ created
# Directory ./review_data/test/ created
# Directory ./review_data/test/0/ created
# Directory ./review_data/test/1/ created
# Directory ./review_data/test/2/ created
# Directory ./review_data/test/3/ created
# Directory ./review_data/test/4/ created
# Directory ./review_data/val/ created
# Directory ./review_data/val/0/ created
# Directory ./review_data/val/1/ created
# Directory ./review_data/val/2/ created
# Directory ./review_data/val/3/ created
# Directory ./review_data/val/4/ created

# %%
# iterate through the train, test, and validation datasets and create individual files. 
# Save in directory structure.

def populate_directory(X, y, train_test_val):
    
    y = y.astype('str')
    
    for i in range(len(df_Wine)):
        try:
            X_item = X[i]
            y_item = y[i]
            
            path = './review_data/' + train_test_val + '/' + y_item
            file = y_item + '_' + str(i) + '.txt'
            
            # Create a file at the designated path
            with open(os.path.join(path, file), 'w') as fp:
                fp.write(X_item)
        except:
            print(f'index {i} not in {train_test_val} tuple')

# %%
populate_directory(X_train, y_train, 'train')
# Out:
# index 1 not in train tuple
# index 4 not in train tuple
# index 13 not in train tuple
# index 21 not in train tuple
# index 26 not in train tuple
# index 29 not in train tuple
# index 34 not in train tuple
# index 39 not in train tuple
# index 41 not in train tuple
# index 47 not in train tuple
# index 48 not in train tuple
# index 49 not in train tuple
# index 50 not in train tuple
# index 51 not in train tuple
# index 53 not in train tuple
# index 58 not in train tuple
# index 63 not in train tuple
# index 69 not in train tuple
# index 70 not in train tuple
# index 73 not in train tuple
# index 79 not in train tuple
# index 82 not in train tuple
# index 87 not in train tuple
# index 89 not in train tuple
# index 92 not in train tuple
# index 104 not in train tuple
# index 107 not in train tuple
# index 122 not in train tuple
# index 123 not in train tuple
# index 126 not in train tuple
# index 129 not in train tuple
# index 133 not in train tuple
# index 137 not in train tuple
# index 139 not in train tuple
# index 145 not in train tuple
# index 152 not in train tuple
# index 153 not in train tuple
# index 155 not in train tuple
# index 161 not in train tuple
# index 166 not in train tuple
# index 167 not in train tuple
# index 170 not in train tuple
# index 171 not in train tuple
# index 177 not in train tuple
# index 187 not in train tuple
# index 188 not in train tuple
# index 201 not in train tuple
# index 204 not in train tuple
# index 206 not in train tuple
# index 213 not in train tuple
# index 214 not in train tuple
# index 215 not in train tuple
# index 220 not in train tuple
# index 221 not in train tuple
# index 229 not in train tuple
# index 234 not in train tuple
# index 240 not in train tuple
# index 247 not in train tuple
# index 249 not in train tuple
# index 250 not in train tuple
# index 257 not in train tuple
# index 258 not in train tuple
# index 269 not in train tuple
# index 271 not in train tuple
# index 275 not in train tuple
# index 276 not in train tuple
# index 278 not in train tuple
# index 280 not in train tuple
# index 287 not in train tuple
# index 290 not in train tuple
# index 292 not in train tuple
# index 294 not in train tuple
# index 300 not in train tuple
# index 315 not in train tuple
# index 316 not in train tuple
# index 326 not in train tuple
# index 344 not in train tuple
# index 356 not in train tuple
# index 357 not in train tuple
# index 358 not in train tuple
# index 365 not in train tuple
# index 371 not in train tuple
# index 379 not in train tuple
# index 380 not in train tuple
# index 381 not in train tuple
# index 384 not in train tuple
# index 389 not in train tuple
# index 406 not in train tuple
# index 408 not in train tuple
# index 414 not in train tuple
# index 425 not in train tuple
# index 430 not in train tuple
# index 435 not in train tuple
# index 447 not in train tuple
# index 456 not in train tuple
# index 460 not in train tuple
# index 461 not in train tuple
# index 465 not in train tuple
# index 468 not in train tuple
# index 472 not in train tuple
# index 481 not in train tuple
# index 488 not in train tuple
# index 491 not in train tuple
# index 494 not in train tuple
# index 495 not in train tuple
# index 497 not in train tuple
# index 499 not in train tuple
# index 506 not in train tuple
# index 515 not in train tuple
# index 517 not in train tuple
# index 532 not in train tuple
# index 534 not in train tuple
# index 536 not in train tuple
# index 546 not in train tuple
# index 548 not in train tuple
# index 549 not in train tuple
# index 557 not in train tuple
# index 564 not in train tuple
# index 565 not in train tuple
# index 568 not in train tuple
# index 569 not in train tuple
# index 570 not in train tuple
# index 571 not in train tuple
# index 575 not in train tuple
# index 577 not in train tuple
# index 580 not in train tuple
# index 584 not in train tuple
# index 596 not in train tuple
# index 605 not in train tuple
# index 606 not in train tuple
# index 610 not in train tuple
# index 619 not in train tuple
# index 624 not in train tuple
# index 634 not in train tuple
# index 636 not in train tuple
# index 638 not in train tuple
# index 648 not in train tuple
# index 650 not in train tuple
# index 652 not in train tuple
# index 654 not in train tuple
# index 655 not in train tuple
# index 658 not in train tuple
# index 669 not in train tuple
# index 673 not in train tuple
# index 674 not in train tuple
# index 678 not in train tuple
# index 680 not in train tuple
# index 682 not in train tuple
# index 689 not in train tuple
# index 694 not in train tuple
# index 697 not in train tuple
# index 699 not in train tuple
# index 702 not in train tuple
# index 703 not in train tuple
# index 708 not in train tuple
# index 710 not in train tuple
# index 711 not in train tuple
# index 715 not in train tuple
# index 717 not in train tuple
# index 719 not in train tuple
# index 725 not in train tuple
# index 727 not in train tuple
# index 733 not in train tuple
# index 739 not in train tuple
# index 742 not in train tuple
# index 743 not in train tuple
# index 752 not in train tuple
# index 761 not in train tuple
# index 765 not in train tuple
# index 773 not in train tuple
# index 779 not in train tuple
# index 787 not in train tuple
# index 791 not in train tuple
# index 794 not in train tuple
# index 795 not in train tuple
# index 803 not in train tuple
# index 805 not in train tuple
# index 810 not in train tuple
# index 816 not in train tuple
# index 824 not in train tuple
# index 826 not in train tuple
# index 835 not in train tuple
# index 836 not in train tuple
# index 841 not in train tuple
# index 845 not in train tuple
# index 850 not in train tuple
# index 852 not in train tuple
# index 853 not in train tuple
# index 855 not in train tuple
# index 857 not in train tuple
# index 865 not in train tuple
# index 871 not in train tuple
# index 880 not in train tuple
# index 881 not in train tuple
# index 884 not in train tuple
# index 887 not in train tuple
# index 894 not in train tuple
# index 897 not in train tuple
# index 901 not in train tuple
# index 903 not in train tuple
# index 904 not in train tuple
# index 911 not in train tuple
# index 916 not in train tuple
# index 919 not in train tuple
# index 920 not in train tuple
# index 921 not in train tuple
# index 922 not in train tuple
# index 923 not in train tuple
# index 926 not in train tuple
# index 927 not in train tuple
# index 928 not in train tuple
# index 929 not in train tuple
# index 943 not in train tuple
# index 949 not in train tuple
# index 952 not in train tuple
# index 953 not in train tuple
# index 954 not in train tuple
# index 959 not in train tuple
# index 960 not in train tuple
# index 968 not in train tuple
# index 970 not in train tuple
# index 973 not in train tuple
# index 974 not in train tuple
# index 977 not in train tuple
# index 978 not in train tuple
# index 985 not in train tuple
# index 987 not in train tuple
# index 993 not in train tuple
# index 995 not in train tuple
# index 996 not in train tuple
# index 1000 not in train tuple
# index 1002 not in train tuple
# index 1005 not in train tuple
# index 1009 not in train tuple
# index 1010 not in train tuple
# index 1018 not in train tuple
# index 1021 not in train tuple
# index 1025 not in train tuple
# index 1026 not in train tuple
# index 1027 not in train tuple
# index 1029 not in train tuple
# index 1033 not in train tuple
# index 1035 not in train tuple
# index 1045 not in train tuple
# index 1049 not in train tuple
# index 1050 not in train tuple
# index 1056 not in train tuple
# index 1058 not in train tuple
# index 1061 not in train tuple
# index 1062 not in train tuple
# index 1063 not in train tuple
# index 1064 not in train tuple
# index 1066 not in train tuple
# index 1069 not in train tuple
# index 1070 not in train tuple
# index 1071 not in train tuple
# index 1073 not in train tuple
# index 1075 not in train tuple
# index 1078 not in train tuple
# index 1080 not in train tuple
# index 1082 not in train tuple
# index 1084 not in train tuple
# index 1089 not in train tuple
# index 1099 not in train tuple
# index 1104 not in train tuple
# index 1105 not in train tuple
# index 1106 not in train tuple
# index 1110 not in train tuple
# index 1111 not in train tuple
# index 1113 not in train tuple
# index 1118 not in train tuple
# index 1123 not in train tuple
# index 1137 not in train tuple
# index 1148 not in train tuple
# index 1149 not in train tuple
# index 1151 not in train tuple
# index 1156 not in train tuple
# index 1158 not in train tuple
# index 1162 not in train tuple
# index 1164 not in train tuple
# index 1165 not in train tuple
# index 1170 not in train tuple
# index 1176 not in train tuple
# index 1185 not in train tuple
# index 1188 not in train tuple
# index 1190 not in train tuple
# index 1195 not in train tuple
# index 1196 not in train tuple
# index 1204 not in train tuple
# index 1207 not in train tuple
# index 1210 not in train tuple
# index 1215 not in train tuple
# index 1219 not in train tuple
# index 1222 not in train tuple
# index 1223 not in train tuple
# index 1224 not in train tuple
# index 1227 not in train tuple
# index 1231 not in train tuple
# index 1233 not in train tuple
# index 1239 not in train tuple
# index 1241 not in train tuple
# index 1248 not in train tuple
# index 1249 not in train tuple
# index 1250 not in train tuple
# index 1253 not in train tuple
# index 1254 not in train tuple
# index 1269 not in train tuple
# index 1270 not in train tuple
# index 1272 not in train tuple
# index 1274 not in train tuple
# index 1282 not in train tuple
# index 1283 not in train tuple
# index 1291 not in train tuple
# index 1296 not in train tuple
# index 1303 not in train tuple
# index 1304 not in train tuple
# index 1305 not in train tuple
# index 1309 not in train tuple
# index 1318 not in train tuple
# index 1321 not in train tuple
# index 1329 not in train tuple
# index 1330 not in train tuple
# index 1333 not in train tuple
# index 1336 not in train tuple
# index 1340 not in train tuple
# index 1342 not in train tuple
# index 1346 not in train tuple
# index 1356 not in train tuple
# index 1358 not in train tuple
# index 1359 not in train tuple
# index 1365 not in train tuple
# index 1366 not in train tuple
# index 1369 not in train tuple
# index 1374 not in train tuple
# index 1388 not in train tuple
# index 1389 not in train tuple
# index 1392 not in train tuple
# index 1397 not in train tuple
# index 1403 not in train tuple
# index 1404 not in train tuple
# index 1411 not in train tuple
# index 1413 not in train tuple
# index 1415 not in train tuple
# index 1416 not in train tuple
# index 1420 not in train tuple
# index 1421 not in train tuple
# index 1426 not in train tuple
# index 1427 not in train tuple
# index 1429 not in train tuple
# index 1431 not in train tuple
# index 1434 not in train tuple
# index 1438 not in train tuple
# index 1446 not in train tuple
# index 1453 not in train tuple
# index 1454 not in train tuple
# index 1457 not in train tuple
# index 1460 not in train tuple
# index 1464 not in train tuple
# index 1468 not in train tuple
# index 1475 not in train tuple
# index 1480 not in train tuple
# index 1481 not in train tuple
# index 1483 not in train tuple
# index 1486 not in train tuple
# index 1487 not in train tuple
# index 1490 not in train tuple
# index 1491 not in train tuple
# index 1500 not in train tuple
# index 1501 not in train tuple
# index 1505 not in train tuple
# index 1519 not in train tuple
# index 1520 not in train tuple
# index 1524 not in train tuple
# index 1525 not in train tuple
# index 1526 not in train tuple
# index 1527 not in train tuple
# index 1537 not in train tuple
# index 1538 not in train tuple
# index 1547 not in train tuple
# index 1553 not in train tuple
# index 1557 not in train tuple
# index 1559 not in train tuple
# index 1563 not in train tuple
# index 1566 not in train tuple
# index 1571 not in train tuple
# index 1575 not in train tuple
# index 1579 not in train tuple
# index 1580 not in train tuple
# index 1582 not in train tuple
# index 1588 not in train tuple
# index 1590 not in train tuple
# index 1591 not in train tuple
# index 1592 not in train tuple
# index 1593 not in train tuple
# index 1594 not in train tuple
# index 1596 not in train tuple
# index 1597 not in train tuple
# index 1598 not in train tuple
# index 1599 not in train tuple
# index 1601 not in train tuple
# index 1603 not in train tuple
# index 1607 not in train tuple
# index 1613 not in train tuple
# index 1614 not in train tuple
# index 1615 not in train tuple
# index 1616 not in train tuple
# index 1628 not in train tuple
# index 1636 not in train tuple
# index 1639 not in train tuple
# index 1640 not in train tuple
# index 1642 not in train tuple
# index 1643 not in train tuple
# index 1645 not in train tuple
# index 1648 not in train tuple
# index 1655 not in train tuple
# index 1662 not in train tuple
# index 1664 not in train tuple
# index 1665 not in train tuple
# index 1670 not in train tuple
# index 1673 not in train tuple
# index 1676 not in train tuple
# index 1677 not in train tuple
# index 1678 not in train tuple
# index 1680 not in train tuple
# index 1681 not in train tuple
# index 1682 not in train tuple
# index 1683 not in train tuple
# index 1684 not in train tuple
# index 1685 not in train tuple
# index 1689 not in train tuple
# index 1695 not in train tuple
# index 1700 not in train tuple
# index 1714 not in train tuple
# index 1716 not in train tuple
# index 1719 not in train tuple
# index 1723 not in train tuple
# index 1727 not in train tuple
# index 1728 not in train tuple
# index 1735 not in train tuple
# index 1736 not in train tuple
# index 1742 not in train tuple
# index 1744 not in train tuple
# index 1748 not in train tuple
# index 1755 not in train tuple
# index 1763 not in train tuple
# index 1771 not in train tuple
# index 1772 not in train tuple
# index 1773 not in train tuple
# index 1780 not in train tuple
# index 1785 not in train tuple
# index 1791 not in train tuple
# index 1792 not in train tuple
# index 1797 not in train tuple
# index 1798 not in train tuple
# index 1803 not in train tuple
# index 1809 not in train tuple
# index 1811 not in train tuple
# index 1814 not in train tuple
# index 1817 not in train tuple
# index 1830 not in train tuple
# index 1831 not in train tuple
# index 1832 not in train tuple
# index 1835 not in train tuple
# index 1841 not in train tuple
# index 1844 not in train tuple
# index 1854 not in train tuple
# index 1860 not in train tuple
# index 1866 not in train tuple
# index 1869 not in train tuple
# index 1870 not in train tuple
# index 1872 not in train tuple
# index 1878 not in train tuple
# index 1880 not in train tuple
# index 1893 not in train tuple
# index 1895 not in train tuple
# index 1897 not in train tuple
# index 1899 not in train tuple
# index 1903 not in train tuple
# index 1914 not in train tuple
# index 1919 not in train tuple
# index 1920 not in train tuple
# index 1924 not in train tuple
# index 1926 not in train tuple
# index 1935 not in train tuple
# index 1937 not in train tuple
# index 1941 not in train tuple
# index 1943 not in train tuple
# index 1946 not in train tuple
# index 1949 not in train tuple
# index 1950 not in train tuple
# index 1951 not in train tuple
# index 1960 not in train tuple
# index 1961 not in train tuple
# index 1964 not in train tuple
# index 1965 not in train tuple
# index 1980 not in train tuple
# index 1989 not in train tuple
# index 1992 not in train tuple
# index 1997 not in train tuple
# index 1998 not in train tuple
# index 1999 not in train tuple
# index 2002 not in train tuple
# index 2004 not in train tuple
# index 2009 not in train tuple
# index 2018 not in train tuple
# index 2032 not in train tuple
# index 2036 not in train tuple
# index 2041 not in train tuple
# index 2048 not in train tuple
# index 2049 not in train tuple
# index 2057 not in train tuple
# index 2060 not in train tuple
# index 2061 not in train tuple
# index 2062 not in train tuple
# index 2063 not in train tuple
# index 2066 not in train tuple
# index 2071 not in train tuple
# index 2073 not in train tuple
# index 2075 not in train tuple
# index 2079 not in train tuple
# index 2081 not in train tuple
# index 2087 not in train tuple
# index 2093 not in train tuple
# index 2095 not in train tuple
# index 2101 not in train tuple
# index 2102 not in train tuple
# index 2103 not in train tuple
# index 2106 not in train tuple
# index 2108 not in train tuple
# index 2112 not in train tuple
# index 2117 not in train tuple
# index 2123 not in train tuple
# index 2126 not in train tuple
# index 2131 not in train tuple
# index 2137 not in train tuple
# index 2141 not in train tuple
# index 2143 not in train tuple
# index 2147 not in train tuple
# index 2156 not in train tuple
# index 2158 not in train tuple
# index 2160 not in train tuple
# index 2162 not in train tuple
# index 2166 not in train tuple
# index 2170 not in train tuple
# index 2195 not in train tuple
# index 2197 not in train tuple
# index 2198 not in train tuple
# index 2200 not in train tuple
# index 2203 not in train tuple
# index 2205 not in train tuple
# index 2210 not in train tuple
# index 2211 not in train tuple
# index 2212 not in train tuple
# index 2213 not in train tuple
# index 2220 not in train tuple
# index 2229 not in train tuple
# index 2230 not in train tuple
# index 2243 not in train tuple
# index 2245 not in train tuple
# index 2246 not in train tuple
# index 2247 not in train tuple
# index 2248 not in train tuple
# index 2255 not in train tuple
# index 2256 not in train tuple
# index 2260 not in train tuple
# index 2263 not in train tuple
# index 2264 not in train tuple
# index 2265 not in train tuple
# index 2270 not in train tuple
# index 2276 not in train tuple
# index 2277 not in train tuple
# index 2300 not in train tuple
# index 2305 not in train tuple
# index 2311 not in train tuple
# index 2312 not in train tuple
# index 2313 not in train tuple
# index 2317 not in train tuple
# index 2319 not in train tuple
# index 2322 not in train tuple
# index 2323 not in train tuple
# index 2326 not in train tuple
# index 2327 not in train tuple
# index 2328 not in train tuple
# index 2331 not in train tuple
# index 2332 not in train tuple
# index 2333 not in train tuple
# index 2344 not in train tuple
# index 2349 not in train tuple
# index 2350 not in train tuple
# index 2370 not in train tuple
# index 2373 not in train tuple
# index 2375 not in train tuple
# index 2376 not in train tuple
# index 2383 not in train tuple
# index 2387 not in train tuple
# index 2388 not in train tuple
# index 2394 not in train tuple
# index 2397 not in train tuple
# index 2399 not in train tuple
# index 2402 not in train tuple
# index 2403 not in train tuple
# index 2407 not in train tuple
# index 2408 not in train tuple
# index 2409 not in train tuple
# index 2411 not in train tuple
# index 2414 not in train tuple
# index 2416 not in train tuple
# index 2420 not in train tuple
# index 2421 not in train tuple
# index 2430 not in train tuple
# index 2432 not in train tuple
# index 2433 not in train tuple
# index 2434 not in train tuple
# index 2436 not in train tuple
# index 2442 not in train tuple
# index 2443 not in train tuple
# index 2448 not in train tuple
# index 2454 not in train tuple
# index 2455 not in train tuple
# index 2462 not in train tuple
# index 2464 not in train tuple
# index 2467 not in train tuple
# index 2472 not in train tuple
# index 2482 not in train tuple
# index 2483 not in train tuple
# index 2490 not in train tuple
# index 2498 not in train tuple
# index 2500 not in train tuple
# index 2503 not in train tuple
# index 2515 not in train tuple
# index 2522 not in train tuple
# index 2523 not in train tuple
# index 2526 not in train tuple
# index 2533 not in train tuple
# index 2535 not in train tuple
# index 2536 not in train tuple
# index 2545 not in train tuple
# index 2552 not in train tuple
# index 2553 not in train tuple
# index 2555 not in train tuple
# index 2564 not in train tuple
# index 2565 not in train tuple
# index 2569 not in train tuple
# index 2570 not in train tuple
# index 2571 not in train tuple
# index 2574 not in train tuple
# index 2576 not in train tuple
# index 2579 not in train tuple
# index 2585 not in train tuple
# index 2586 not in train tuple
# index 2590 not in train tuple
# index 2593 not in train tuple
# index 2598 not in train tuple
# index 2599 not in train tuple
# index 2602 not in train tuple
# index 2603 not in train tuple
# index 2605 not in train tuple
# index 2613 not in train tuple
# index 2621 not in train tuple
# index 2622 not in train tuple
# index 2627 not in train tuple
# index 2628 not in train tuple
# index 2633 not in train tuple
# index 2635 not in train tuple
# index 2636 not in train tuple
# index 2637 not in train tuple
# index 2639 not in train tuple
# index 2640 not in train tuple
# index 2641 not in train tuple
# index 2655 not in train tuple
# index 2656 not in train tuple
# index 2658 not in train tuple
# index 2665 not in train tuple
# index 2669 not in train tuple
# index 2670 not in train tuple
# index 2676 not in train tuple
# index 2678 not in train tuple
# index 2680 not in train tuple
# index 2687 not in train tuple
# index 2691 not in train tuple
# index 2693 not in train tuple
# index 2699 not in train tuple
# index 2701 not in train tuple
# index 2705 not in train tuple
# index 2706 not in train tuple
# index 2707 not in train tuple
# index 2717 not in train tuple
# index 2718 not in train tuple
# index 2724 not in train tuple
# index 2727 not in train tuple
# index 2736 not in train tuple
# index 2741 not in train tuple
# index 2743 not in train tuple
# index 2746 not in train tuple
# index 2748 not in train tuple
# index 2750 not in train tuple
# index 2759 not in train tuple
# index 2760 not in train tuple
# index 2763 not in train tuple
# index 2768 not in train tuple
# index 2772 not in train tuple
# index 2776 not in train tuple
# index 2788 not in train tuple
# index 2791 not in train tuple
# index 2796 not in train tuple
# index 2802 not in train tuple
# index 2803 not in train tuple
# index 2804 not in train tuple
# index 2814 not in train tuple
# index 2828 not in train tuple
# index 2830 not in train tuple
# index 2835 not in train tuple
# index 2848 not in train tuple
# index 2851 not in train tuple
# index 2852 not in train tuple
# index 2854 not in train tuple
# index 2858 not in train tuple
# index 2871 not in train tuple
# index 2873 not in train tuple
# index 2874 not in train tuple
# index 2880 not in train tuple
# index 2882 not in train tuple
# index 2884 not in train tuple
# index 2894 not in train tuple
# index 2896 not in train tuple
# index 2898 not in train tuple
# index 2900 not in train tuple
# index 2901 not in train tuple
# index 2902 not in train tuple
# index 2906 not in train tuple
# index 2908 not in train tuple
# index 2909 not in train tuple
# index 2912 not in train tuple
# index 2919 not in train tuple
# index 2926 not in train tuple
# index 2928 not in train tuple
# index 2937 not in train tuple
# index 2940 not in train tuple
# index 2951 not in train tuple
# index 2953 not in train tuple
# index 2968 not in train tuple
# index 2969 not in train tuple
# index 2971 not in train tuple
# index 2980 not in train tuple
# index 2987 not in train tuple
# index 2990 not in train tuple
# index 2992 not in train tuple
# index 2994 not in train tuple
# index 2997 not in train tuple
# index 2999 not in train tuple
# index 3000 not in train tuple
# index 3002 not in train tuple
# index 3004 not in train tuple
# index 3007 not in train tuple
# index 3009 not in train tuple
# index 3011 not in train tuple
# index 3013 not in train tuple
# index 3021 not in train tuple
# index 3025 not in train tuple
# index 3026 not in train tuple
# index 3030 not in train tuple
# index 3032 not in train tuple
# index 3034 not in train tuple
# index 3036 not in train tuple
# index 3038 not in train tuple
# index 3040 not in train tuple
# index 3042 not in train tuple
# index 3050 not in train tuple
# index 3055 not in train tuple
# index 3059 not in train tuple
# index 3061 not in train tuple
# index 3071 not in train tuple
# index 3074 not in train tuple
# index 3078 not in train tuple
# index 3087 not in train tuple
# index 3091 not in train tuple
# index 3093 not in train tuple
# index 3094 not in train tuple
# index 3095 not in train tuple
# index 3097 not in train tuple
# index 3098 not in train tuple
# index 3102 not in train tuple
# index 3105 not in train tuple
# index 3111 not in train tuple
# index 3112 not in train tuple
# index 3115 not in train tuple
# index 3118 not in train tuple
# index 3121 not in train tuple
# index 3124 not in train tuple
# index 3130 not in train tuple
# index 3133 not in train tuple
# index 3134 not in train tuple
# index 3135 not in train tuple
# index 3141 not in train tuple
# index 3143 not in train tuple
# index 3147 not in train tuple
# index 3155 not in train tuple
# index 3157 not in train tuple
# index 3162 not in train tuple
# index 3163 not in train tuple
# index 3174 not in train tuple
# index 3176 not in train tuple
# index 3177 not in train tuple
# index 3182 not in train tuple
# index 3184 not in train tuple
# index 3186 not in train tuple
# index 3187 not in train tuple
# index 3188 not in train tuple
# index 3191 not in train tuple
# index 3192 not in train tuple
# index 3194 not in train tuple
# index 3196 not in train tuple
# index 3197 not in train tuple
# index 3208 not in train tuple
# index 3210 not in train tuple
# index 3215 not in train tuple
# index 3217 not in train tuple
# index 3219 not in train tuple
# index 3223 not in train tuple
# index 3228 not in train tuple
# index 3230 not in train tuple
# index 3234 not in train tuple
# index 3236 not in train tuple
# index 3237 not in train tuple
# index 3238 not in train tuple
# index 3246 not in train tuple
# index 3253 not in train tuple
# index 3255 not in train tuple
# index 3260 not in train tuple
# index 3263 not in train tuple
# index 3267 not in train tuple
# index 3271 not in train tuple
# index 3273 not in train tuple
# index 3276 not in train tuple
# index 3278 not in train tuple
# index 3293 not in train tuple
# index 3294 not in train tuple
# index 3296 not in train tuple
# index 3297 not in train tuple

# %%
populate_directory(X_test, y_test, 'test')
# Out:
# index 0 not in test tuple
# index 1 not in test tuple
# index 2 not in test tuple
# index 3 not in test tuple
# index 5 not in test tuple
# index 6 not in test tuple
# index 7 not in test tuple
# index 8 not in test tuple
# index 9 not in test tuple
# index 10 not in test tuple
# index 11 not in test tuple
# index 12 not in test tuple
# index 14 not in test tuple
# index 15 not in test tuple
# index 16 not in test tuple
# index 17 not in test tuple
# index 18 not in test tuple
# index 19 not in test tuple
# index 20 not in test tuple
# index 21 not in test tuple
# index 22 not in test tuple
# index 23 not in test tuple
# index 24 not in test tuple
# index 25 not in test tuple
# index 26 not in test tuple
# index 27 not in test tuple
# index 28 not in test tuple
# index 30 not in test tuple
# index 31 not in test tuple
# index 32 not in test tuple
# index 33 not in test tuple
# index 35 not in test tuple
# index 36 not in test tuple
# index 37 not in test tuple
# index 38 not in test tuple
# index 40 not in test tuple
# index 41 not in test tuple
# index 42 not in test tuple
# index 43 not in test tuple
# index 44 not in test tuple
# index 45 not in test tuple
# index 46 not in test tuple
# index 47 not in test tuple
# index 48 not in test tuple
# index 49 not in test tuple
# index 52 not in test tuple
# index 54 not in test tuple
# index 55 not in test tuple
# index 56 not in test tuple
# index 57 not in test tuple
# index 58 not in test tuple
# index 59 not in test tuple
# index 60 not in test tuple
# index 61 not in test tuple
# index 62 not in test tuple
# index 63 not in test tuple
# index 64 not in test tuple
# index 65 not in test tuple
# index 66 not in test tuple
# index 67 not in test tuple
# index 68 not in test tuple
# index 70 not in test tuple
# index 71 not in test tuple
# index 72 not in test tuple
# index 73 not in test tuple
# index 74 not in test tuple
# index 75 not in test tuple
# index 76 not in test tuple
# index 77 not in test tuple
# index 78 not in test tuple
# index 80 not in test tuple
# index 81 not in test tuple
# index 82 not in test tuple
# index 83 not in test tuple
# index 84 not in test tuple
# index 85 not in test tuple
# index 86 not in test tuple
# index 88 not in test tuple
# index 89 not in test tuple
# index 90 not in test tuple
# index 91 not in test tuple
# index 93 not in test tuple
# index 94 not in test tuple
# index 95 not in test tuple
# index 96 not in test tuple
# index 97 not in test tuple
# index 98 not in test tuple
# index 99 not in test tuple
# index 100 not in test tuple
# index 101 not in test tuple
# index 102 not in test tuple
# index 103 not in test tuple
# index 105 not in test tuple
# index 106 not in test tuple
# index 108 not in test tuple
# index 109 not in test tuple
# index 110 not in test tuple
# index 111 not in test tuple
# index 112 not in test tuple
# index 113 not in test tuple
# index 114 not in test tuple
# index 115 not in test tuple
# index 116 not in test tuple
# index 117 not in test tuple
# index 118 not in test tuple
# index 119 not in test tuple
# index 120 not in test tuple
# index 121 not in test tuple
# index 123 not in test tuple
# index 124 not in test tuple
# index 125 not in test tuple
# index 126 not in test tuple
# index 127 not in test tuple
# index 128 not in test tuple
# index 130 not in test tuple
# index 131 not in test tuple
# index 132 not in test tuple
# index 134 not in test tuple
# index 135 not in test tuple
# index 136 not in test tuple
# index 137 not in test tuple
# index 138 not in test tuple
# index 139 not in test tuple
# index 140 not in test tuple
# index 141 not in test tuple
# index 142 not in test tuple
# index 143 not in test tuple
# index 144 not in test tuple
# index 145 not in test tuple
# index 146 not in test tuple
# index 147 not in test tuple
# index 148 not in test tuple
# index 149 not in test tuple
# index 150 not in test tuple
# index 151 not in test tuple
# index 153 not in test tuple
# index 154 not in test tuple
# index 156 not in test tuple
# index 157 not in test tuple
# index 158 not in test tuple
# index 159 not in test tuple
# index 160 not in test tuple
# index 161 not in test tuple
# index 162 not in test tuple
# index 163 not in test tuple
# index 164 not in test tuple
# index 165 not in test tuple
# index 166 not in test tuple
# index 168 not in test tuple
# index 169 not in test tuple
# index 170 not in test tuple
# index 171 not in test tuple
# index 172 not in test tuple
# index 173 not in test tuple
# index 174 not in test tuple
# index 175 not in test tuple
# index 176 not in test tuple
# index 177 not in test tuple
# index 178 not in test tuple
# index 179 not in test tuple
# index 180 not in test tuple
# index 181 not in test tuple
# index 182 not in test tuple
# index 183 not in test tuple
# index 184 not in test tuple
# index 185 not in test tuple
# index 186 not in test tuple
# index 187 not in test tuple
# index 189 not in test tuple
# index 190 not in test tuple
# index 191 not in test tuple
# index 192 not in test tuple
# index 193 not in test tuple
# index 194 not in test tuple
# index 195 not in test tuple
# index 196 not in test tuple
# index 197 not in test tuple
# index 198 not in test tuple
# index 199 not in test tuple
# index 200 not in test tuple
# index 201 not in test tuple
# index 202 not in test tuple
# index 203 not in test tuple
# index 204 not in test tuple
# index 205 not in test tuple
# index 207 not in test tuple
# index 208 not in test tuple
# index 209 not in test tuple
# index 210 not in test tuple
# index 211 not in test tuple
# index 212 not in test tuple
# index 213 not in test tuple
# index 216 not in test tuple
# index 217 not in test tuple
# index 218 not in test tuple
# index 219 not in test tuple
# index 222 not in test tuple
# index 223 not in test tuple
# index 224 not in test tuple
# index 225 not in test tuple
# index 226 not in test tuple
# index 227 not in test tuple
# index 228 not in test tuple
# index 230 not in test tuple
# index 231 not in test tuple
# index 232 not in test tuple
# index 233 not in test tuple
# index 235 not in test tuple
# index 236 not in test tuple
# index 237 not in test tuple
# index 238 not in test tuple
# index 239 not in test tuple
# index 240 not in test tuple
# index 241 not in test tuple
# index 242 not in test tuple
# index 243 not in test tuple
# index 244 not in test tuple
# index 245 not in test tuple
# index 246 not in test tuple
# index 248 not in test tuple
# index 249 not in test tuple
# index 251 not in test tuple
# index 252 not in test tuple
# index 253 not in test tuple
# index 254 not in test tuple
# index 255 not in test tuple
# index 256 not in test tuple
# index 258 not in test tuple
# index 259 not in test tuple
# index 260 not in test tuple
# index 261 not in test tuple
# index 262 not in test tuple
# index 263 not in test tuple
# index 264 not in test tuple
# index 265 not in test tuple
# index 266 not in test tuple
# index 267 not in test tuple
# index 268 not in test tuple
# index 269 not in test tuple
# index 270 not in test tuple
# index 271 not in test tuple
# index 272 not in test tuple
# index 273 not in test tuple
# index 274 not in test tuple
# index 277 not in test tuple
# index 278 not in test tuple
# index 279 not in test tuple
# index 280 not in test tuple
# index 281 not in test tuple
# index 282 not in test tuple
# index 283 not in test tuple
# index 284 not in test tuple
# index 285 not in test tuple
# index 286 not in test tuple
# index 287 not in test tuple
# index 288 not in test tuple
# index 289 not in test tuple
# index 291 not in test tuple
# index 292 not in test tuple
# index 293 not in test tuple
# index 294 not in test tuple
# index 295 not in test tuple
# index 296 not in test tuple
# index 297 not in test tuple
# index 298 not in test tuple
# index 299 not in test tuple
# index 301 not in test tuple
# index 302 not in test tuple
# index 303 not in test tuple
# index 304 not in test tuple
# index 305 not in test tuple
# index 306 not in test tuple
# index 307 not in test tuple
# index 308 not in test tuple
# index 309 not in test tuple
# index 310 not in test tuple
# index 311 not in test tuple
# index 312 not in test tuple
# index 313 not in test tuple
# index 314 not in test tuple
# index 317 not in test tuple
# index 318 not in test tuple
# index 319 not in test tuple
# index 320 not in test tuple
# index 321 not in test tuple
# index 322 not in test tuple
# index 323 not in test tuple
# index 324 not in test tuple
# index 325 not in test tuple
# index 326 not in test tuple
# index 327 not in test tuple
# index 328 not in test tuple
# index 329 not in test tuple
# index 330 not in test tuple
# index 331 not in test tuple
# index 332 not in test tuple
# index 333 not in test tuple
# index 334 not in test tuple
# index 335 not in test tuple
# index 336 not in test tuple
# index 337 not in test tuple
# index 338 not in test tuple
# index 339 not in test tuple
# index 340 not in test tuple
# index 341 not in test tuple
# index 342 not in test tuple
# index 343 not in test tuple
# index 344 not in test tuple
# index 345 not in test tuple
# index 346 not in test tuple
# index 347 not in test tuple
# index 348 not in test tuple
# index 349 not in test tuple
# index 350 not in test tuple
# index 351 not in test tuple
# index 352 not in test tuple
# index 353 not in test tuple
# index 354 not in test tuple
# index 355 not in test tuple
# index 357 not in test tuple
# index 359 not in test tuple
# index 360 not in test tuple
# index 361 not in test tuple
# index 362 not in test tuple
# index 363 not in test tuple
# index 364 not in test tuple
# index 365 not in test tuple
# index 366 not in test tuple
# index 367 not in test tuple
# index 368 not in test tuple
# index 369 not in test tuple
# index 370 not in test tuple
# index 371 not in test tuple
# index 372 not in test tuple
# index 373 not in test tuple
# index 374 not in test tuple
# index 375 not in test tuple
# index 376 not in test tuple
# index 377 not in test tuple
# index 378 not in test tuple
# index 382 not in test tuple
# index 383 not in test tuple
# index 384 not in test tuple
# index 385 not in test tuple
# index 386 not in test tuple
# index 387 not in test tuple
# index 388 not in test tuple
# index 389 not in test tuple
# index 390 not in test tuple
# index 391 not in test tuple
# index 392 not in test tuple
# index 393 not in test tuple
# index 394 not in test tuple
# index 395 not in test tuple
# index 396 not in test tuple
# index 397 not in test tuple
# index 398 not in test tuple
# index 399 not in test tuple
# index 400 not in test tuple
# index 401 not in test tuple
# index 402 not in test tuple
# index 403 not in test tuple
# index 404 not in test tuple
# index 405 not in test tuple
# index 407 not in test tuple
# index 409 not in test tuple
# index 410 not in test tuple
# index 411 not in test tuple
# index 412 not in test tuple
# index 413 not in test tuple
# index 415 not in test tuple
# index 416 not in test tuple
# index 417 not in test tuple
# index 418 not in test tuple
# index 419 not in test tuple
# index 420 not in test tuple
# index 421 not in test tuple
# index 422 not in test tuple
# index 423 not in test tuple
# index 424 not in test tuple
# index 425 not in test tuple
# index 426 not in test tuple
# index 427 not in test tuple
# index 428 not in test tuple
# index 429 not in test tuple
# index 431 not in test tuple
# index 432 not in test tuple
# index 433 not in test tuple
# index 434 not in test tuple
# index 435 not in test tuple
# index 436 not in test tuple
# index 437 not in test tuple
# index 438 not in test tuple
# index 439 not in test tuple
# index 440 not in test tuple
# index 441 not in test tuple
# index 442 not in test tuple
# index 443 not in test tuple
# index 444 not in test tuple
# index 445 not in test tuple
# index 446 not in test tuple
# index 447 not in test tuple
# index 448 not in test tuple
# index 449 not in test tuple
# index 450 not in test tuple
# index 451 not in test tuple
# index 452 not in test tuple
# index 453 not in test tuple
# index 454 not in test tuple
# index 455 not in test tuple
# index 457 not in test tuple
# index 458 not in test tuple
# index 459 not in test tuple
# index 461 not in test tuple
# index 462 not in test tuple
# index 463 not in test tuple
# index 464 not in test tuple
# index 466 not in test tuple
# index 467 not in test tuple
# index 469 not in test tuple
# index 470 not in test tuple
# index 471 not in test tuple
# index 472 not in test tuple
# index 473 not in test tuple
# index 474 not in test tuple
# index 475 not in test tuple
# index 476 not in test tuple
# index 477 not in test tuple
# index 478 not in test tuple
# index 479 not in test tuple
# index 480 not in test tuple
# index 482 not in test tuple
# index 483 not in test tuple
# index 484 not in test tuple
# index 485 not in test tuple
# index 486 not in test tuple
# index 487 not in test tuple
# index 488 not in test tuple
# index 489 not in test tuple
# index 490 not in test tuple
# index 492 not in test tuple
# index 493 not in test tuple
# index 494 not in test tuple
# index 496 not in test tuple
# index 497 not in test tuple
# index 498 not in test tuple
# index 499 not in test tuple
# index 500 not in test tuple
# index 501 not in test tuple
# index 502 not in test tuple
# index 503 not in test tuple
# index 504 not in test tuple
# index 505 not in test tuple
# index 507 not in test tuple
# index 508 not in test tuple
# index 509 not in test tuple
# index 510 not in test tuple
# index 511 not in test tuple
# index 512 not in test tuple
# index 513 not in test tuple
# index 514 not in test tuple
# index 516 not in test tuple
# index 517 not in test tuple
# index 518 not in test tuple
# index 519 not in test tuple
# index 520 not in test tuple
# index 521 not in test tuple
# index 522 not in test tuple
# index 523 not in test tuple
# index 524 not in test tuple
# index 525 not in test tuple
# index 526 not in test tuple
# index 527 not in test tuple
# index 528 not in test tuple
# index 529 not in test tuple
# index 530 not in test tuple
# index 531 not in test tuple
# index 532 not in test tuple
# index 533 not in test tuple
# index 535 not in test tuple
# index 536 not in test tuple
# index 537 not in test tuple
# index 538 not in test tuple
# index 539 not in test tuple
# index 540 not in test tuple
# index 541 not in test tuple
# index 542 not in test tuple
# index 543 not in test tuple
# index 544 not in test tuple
# index 545 not in test tuple
# index 547 not in test tuple
# index 548 not in test tuple
# index 550 not in test tuple
# index 551 not in test tuple
# index 552 not in test tuple
# index 553 not in test tuple
# index 554 not in test tuple
# index 555 not in test tuple
# index 556 not in test tuple
# index 558 not in test tuple
# index 559 not in test tuple
# index 560 not in test tuple
# index 561 not in test tuple
# index 562 not in test tuple
# index 563 not in test tuple
# index 565 not in test tuple
# index 566 not in test tuple
# index 567 not in test tuple
# index 570 not in test tuple
# index 572 not in test tuple
# index 573 not in test tuple
# index 574 not in test tuple
# index 576 not in test tuple
# index 578 not in test tuple
# index 579 not in test tuple
# index 581 not in test tuple
# index 582 not in test tuple
# index 583 not in test tuple
# index 584 not in test tuple
# index 585 not in test tuple
# index 586 not in test tuple
# index 587 not in test tuple
# index 588 not in test tuple
# index 589 not in test tuple
# index 590 not in test tuple
# index 591 not in test tuple
# index 592 not in test tuple
# index 593 not in test tuple
# index 594 not in test tuple
# index 595 not in test tuple
# index 597 not in test tuple
# index 598 not in test tuple
# index 599 not in test tuple
# index 600 not in test tuple
# index 601 not in test tuple
# index 602 not in test tuple
# index 603 not in test tuple
# index 604 not in test tuple
# index 605 not in test tuple
# index 607 not in test tuple
# index 608 not in test tuple
# index 609 not in test tuple
# index 610 not in test tuple
# index 611 not in test tuple
# index 612 not in test tuple
# index 613 not in test tuple
# index 614 not in test tuple
# index 615 not in test tuple
# index 616 not in test tuple
# index 617 not in test tuple
# index 618 not in test tuple
# index 619 not in test tuple
# index 620 not in test tuple
# index 621 not in test tuple
# index 622 not in test tuple
# index 623 not in test tuple
# index 625 not in test tuple
# index 626 not in test tuple
# index 627 not in test tuple
# index 628 not in test tuple
# index 629 not in test tuple
# index 630 not in test tuple
# index 631 not in test tuple
# index 632 not in test tuple
# index 633 not in test tuple
# index 635 not in test tuple
# index 636 not in test tuple
# index 637 not in test tuple
# index 638 not in test tuple
# index 639 not in test tuple
# index 640 not in test tuple
# index 641 not in test tuple
# index 642 not in test tuple
# index 643 not in test tuple
# index 644 not in test tuple
# index 645 not in test tuple
# index 646 not in test tuple
# index 647 not in test tuple
# index 648 not in test tuple
# index 649 not in test tuple
# index 651 not in test tuple
# index 652 not in test tuple
# index 653 not in test tuple
# index 655 not in test tuple
# index 656 not in test tuple
# index 657 not in test tuple
# index 659 not in test tuple
# index 660 not in test tuple
# index 661 not in test tuple
# index 662 not in test tuple
# index 663 not in test tuple
# index 664 not in test tuple
# index 665 not in test tuple
# index 666 not in test tuple
# index 667 not in test tuple
# index 668 not in test tuple
# index 670 not in test tuple
# index 671 not in test tuple
# index 672 not in test tuple
# index 675 not in test tuple
# index 676 not in test tuple
# index 677 not in test tuple
# index 678 not in test tuple
# index 679 not in test tuple
# index 681 not in test tuple
# index 683 not in test tuple
# index 684 not in test tuple
# index 685 not in test tuple
# index 686 not in test tuple
# index 687 not in test tuple
# index 688 not in test tuple
# index 689 not in test tuple
# index 690 not in test tuple
# index 691 not in test tuple
# index 692 not in test tuple
# index 693 not in test tuple
# index 694 not in test tuple
# index 695 not in test tuple
# index 696 not in test tuple
# index 697 not in test tuple
# index 698 not in test tuple
# index 700 not in test tuple
# index 701 not in test tuple
# index 702 not in test tuple
# index 704 not in test tuple
# index 705 not in test tuple
# index 706 not in test tuple
# index 707 not in test tuple
# index 709 not in test tuple
# index 710 not in test tuple
# index 711 not in test tuple
# index 712 not in test tuple
# index 713 not in test tuple
# index 714 not in test tuple
# index 715 not in test tuple
# index 716 not in test tuple
# index 717 not in test tuple
# index 718 not in test tuple
# index 720 not in test tuple
# index 721 not in test tuple
# index 722 not in test tuple
# index 723 not in test tuple
# index 724 not in test tuple
# index 726 not in test tuple
# index 728 not in test tuple
# index 729 not in test tuple
# index 730 not in test tuple
# index 731 not in test tuple
# index 732 not in test tuple
# index 733 not in test tuple
# index 734 not in test tuple
# index 735 not in test tuple
# index 736 not in test tuple
# index 737 not in test tuple
# index 738 not in test tuple
# index 740 not in test tuple
# index 741 not in test tuple
# index 742 not in test tuple
# index 743 not in test tuple
# index 744 not in test tuple
# index 745 not in test tuple
# index 746 not in test tuple
# index 747 not in test tuple
# index 748 not in test tuple
# index 749 not in test tuple
# index 750 not in test tuple
# index 751 not in test tuple
# index 753 not in test tuple
# index 754 not in test tuple
# index 755 not in test tuple
# index 756 not in test tuple
# index 757 not in test tuple
# index 758 not in test tuple
# index 759 not in test tuple
# index 760 not in test tuple
# index 761 not in test tuple
# index 762 not in test tuple
# index 763 not in test tuple
# index 764 not in test tuple
# index 766 not in test tuple
# index 767 not in test tuple
# index 768 not in test tuple
# index 769 not in test tuple
# index 770 not in test tuple
# index 771 not in test tuple
# index 772 not in test tuple
# index 774 not in test tuple
# index 775 not in test tuple
# index 776 not in test tuple
# index 777 not in test tuple
# index 778 not in test tuple
# index 780 not in test tuple
# index 781 not in test tuple
# index 782 not in test tuple
# index 783 not in test tuple
# index 784 not in test tuple
# index 785 not in test tuple
# index 786 not in test tuple
# index 788 not in test tuple
# index 789 not in test tuple
# index 790 not in test tuple
# index 791 not in test tuple
# index 792 not in test tuple
# index 793 not in test tuple
# index 796 not in test tuple
# index 797 not in test tuple
# index 798 not in test tuple
# index 799 not in test tuple
# index 800 not in test tuple
# index 801 not in test tuple
# index 802 not in test tuple
# index 804 not in test tuple
# index 806 not in test tuple
# index 807 not in test tuple
# index 808 not in test tuple
# index 809 not in test tuple
# index 811 not in test tuple
# index 812 not in test tuple
# index 813 not in test tuple
# index 814 not in test tuple
# index 815 not in test tuple
# index 816 not in test tuple
# index 817 not in test tuple
# index 818 not in test tuple
# index 819 not in test tuple
# index 820 not in test tuple
# index 821 not in test tuple
# index 822 not in test tuple
# index 823 not in test tuple
# index 824 not in test tuple
# index 825 not in test tuple
# index 826 not in test tuple
# index 827 not in test tuple
# index 828 not in test tuple
# index 829 not in test tuple
# index 830 not in test tuple
# index 831 not in test tuple
# index 832 not in test tuple
# index 833 not in test tuple
# index 834 not in test tuple
# index 835 not in test tuple
# index 836 not in test tuple
# index 837 not in test tuple
# index 838 not in test tuple
# index 839 not in test tuple
# index 840 not in test tuple
# index 842 not in test tuple
# index 843 not in test tuple
# index 844 not in test tuple
# index 845 not in test tuple
# index 846 not in test tuple
# index 847 not in test tuple
# index 848 not in test tuple
# index 849 not in test tuple
# index 851 not in test tuple
# index 852 not in test tuple
# index 853 not in test tuple
# index 854 not in test tuple
# index 855 not in test tuple
# index 856 not in test tuple
# index 858 not in test tuple
# index 859 not in test tuple
# index 860 not in test tuple
# index 861 not in test tuple
# index 862 not in test tuple
# index 863 not in test tuple
# index 864 not in test tuple
# index 866 not in test tuple
# index 867 not in test tuple
# index 868 not in test tuple
# index 869 not in test tuple
# index 870 not in test tuple
# index 871 not in test tuple
# index 872 not in test tuple
# index 873 not in test tuple
# index 874 not in test tuple
# index 875 not in test tuple
# index 876 not in test tuple
# index 877 not in test tuple
# index 878 not in test tuple
# index 879 not in test tuple
# index 880 not in test tuple
# index 882 not in test tuple
# index 883 not in test tuple
# index 884 not in test tuple
# index 885 not in test tuple
# index 886 not in test tuple
# index 888 not in test tuple
# index 889 not in test tuple
# index 890 not in test tuple
# index 891 not in test tuple
# index 892 not in test tuple
# index 893 not in test tuple
# index 894 not in test tuple
# index 895 not in test tuple
# index 896 not in test tuple
# index 897 not in test tuple
# index 898 not in test tuple
# index 899 not in test tuple
# index 900 not in test tuple
# index 902 not in test tuple
# index 904 not in test tuple
# index 905 not in test tuple
# index 906 not in test tuple
# index 907 not in test tuple
# index 908 not in test tuple
# index 909 not in test tuple
# index 910 not in test tuple
# index 911 not in test tuple
# index 912 not in test tuple
# index 913 not in test tuple
# index 914 not in test tuple
# index 915 not in test tuple
# index 916 not in test tuple
# index 917 not in test tuple
# index 918 not in test tuple
# index 920 not in test tuple
# index 923 not in test tuple
# index 924 not in test tuple
# index 925 not in test tuple
# index 929 not in test tuple
# index 930 not in test tuple
# index 931 not in test tuple
# index 932 not in test tuple
# index 933 not in test tuple
# index 934 not in test tuple
# index 935 not in test tuple
# index 936 not in test tuple
# index 937 not in test tuple
# index 938 not in test tuple
# index 939 not in test tuple
# index 940 not in test tuple
# index 941 not in test tuple
# index 942 not in test tuple
# index 943 not in test tuple
# index 944 not in test tuple
# index 945 not in test tuple
# index 946 not in test tuple
# index 947 not in test tuple
# index 948 not in test tuple
# index 949 not in test tuple
# index 950 not in test tuple
# index 951 not in test tuple
# index 953 not in test tuple
# index 955 not in test tuple
# index 956 not in test tuple
# index 957 not in test tuple
# index 958 not in test tuple
# index 960 not in test tuple
# index 961 not in test tuple
# index 962 not in test tuple
# index 963 not in test tuple
# index 964 not in test tuple
# index 965 not in test tuple
# index 966 not in test tuple
# index 967 not in test tuple
# index 968 not in test tuple
# index 969 not in test tuple
# index 971 not in test tuple
# index 972 not in test tuple
# index 975 not in test tuple
# index 976 not in test tuple
# index 978 not in test tuple
# index 979 not in test tuple
# index 980 not in test tuple
# index 981 not in test tuple
# index 982 not in test tuple
# index 983 not in test tuple
# index 984 not in test tuple
# index 986 not in test tuple
# index 987 not in test tuple
# index 988 not in test tuple
# index 989 not in test tuple
# index 990 not in test tuple
# index 991 not in test tuple
# index 992 not in test tuple
# index 993 not in test tuple
# index 994 not in test tuple
# index 996 not in test tuple
# index 997 not in test tuple
# index 998 not in test tuple
# index 999 not in test tuple
# index 1001 not in test tuple
# index 1003 not in test tuple
# index 1004 not in test tuple
# index 1006 not in test tuple
# index 1007 not in test tuple
# index 1008 not in test tuple
# index 1010 not in test tuple
# index 1011 not in test tuple
# index 1012 not in test tuple
# index 1013 not in test tuple
# index 1014 not in test tuple
# index 1015 not in test tuple
# index 1016 not in test tuple
# index 1017 not in test tuple
# index 1018 not in test tuple
# index 1019 not in test tuple
# index 1020 not in test tuple
# index 1021 not in test tuple
# index 1022 not in test tuple
# index 1023 not in test tuple
# index 1024 not in test tuple
# index 1027 not in test tuple
# index 1028 not in test tuple
# index 1029 not in test tuple
# index 1030 not in test tuple
# index 1031 not in test tuple
# index 1032 not in test tuple
# index 1033 not in test tuple
# index 1034 not in test tuple
# index 1036 not in test tuple
# index 1037 not in test tuple
# index 1038 not in test tuple
# index 1039 not in test tuple
# index 1040 not in test tuple
# index 1041 not in test tuple
# index 1042 not in test tuple
# index 1043 not in test tuple
# index 1044 not in test tuple
# index 1046 not in test tuple
# index 1047 not in test tuple
# index 1048 not in test tuple
# index 1049 not in test tuple
# index 1051 not in test tuple
# index 1052 not in test tuple
# index 1053 not in test tuple
# index 1054 not in test tuple
# index 1055 not in test tuple
# index 1056 not in test tuple
# index 1057 not in test tuple
# index 1059 not in test tuple
# index 1060 not in test tuple
# index 1061 not in test tuple
# index 1063 not in test tuple
# index 1064 not in test tuple
# index 1065 not in test tuple
# index 1066 not in test tuple
# index 1067 not in test tuple
# index 1068 not in test tuple
# index 1070 not in test tuple
# index 1072 not in test tuple
# index 1074 not in test tuple
# index 1075 not in test tuple
# index 1076 not in test tuple
# index 1077 not in test tuple
# index 1079 not in test tuple
# index 1081 not in test tuple
# index 1083 not in test tuple
# index 1084 not in test tuple
# index 1085 not in test tuple
# index 1086 not in test tuple
# index 1087 not in test tuple
# index 1088 not in test tuple
# index 1089 not in test tuple
# index 1090 not in test tuple
# index 1091 not in test tuple
# index 1092 not in test tuple
# index 1093 not in test tuple
# index 1094 not in test tuple
# index 1095 not in test tuple
# index 1096 not in test tuple
# index 1097 not in test tuple
# index 1098 not in test tuple
# index 1100 not in test tuple
# index 1101 not in test tuple
# index 1102 not in test tuple
# index 1103 not in test tuple
# index 1104 not in test tuple
# index 1106 not in test tuple
# index 1107 not in test tuple
# index 1108 not in test tuple
# index 1109 not in test tuple
# index 1110 not in test tuple
# index 1111 not in test tuple
# index 1112 not in test tuple
# index 1113 not in test tuple
# index 1114 not in test tuple
# index 1115 not in test tuple
# index 1116 not in test tuple
# index 1117 not in test tuple
# index 1119 not in test tuple
# index 1120 not in test tuple
# index 1121 not in test tuple
# index 1122 not in test tuple
# index 1124 not in test tuple
# index 1125 not in test tuple
# index 1126 not in test tuple
# index 1127 not in test tuple
# index 1128 not in test tuple
# index 1129 not in test tuple
# index 1130 not in test tuple
# index 1131 not in test tuple
# index 1132 not in test tuple
# index 1133 not in test tuple
# index 1134 not in test tuple
# index 1135 not in test tuple
# index 1136 not in test tuple
# index 1137 not in test tuple
# index 1138 not in test tuple
# index 1139 not in test tuple
# index 1140 not in test tuple
# index 1141 not in test tuple
# index 1142 not in test tuple
# index 1143 not in test tuple
# index 1144 not in test tuple
# index 1145 not in test tuple
# index 1146 not in test tuple
# index 1147 not in test tuple
# index 1148 not in test tuple
# index 1149 not in test tuple
# index 1150 not in test tuple
# index 1152 not in test tuple
# index 1153 not in test tuple
# index 1154 not in test tuple
# index 1155 not in test tuple
# index 1157 not in test tuple
# index 1159 not in test tuple
# index 1160 not in test tuple
# index 1161 not in test tuple
# index 1163 not in test tuple
# index 1165 not in test tuple
# index 1166 not in test tuple
# index 1167 not in test tuple
# index 1168 not in test tuple
# index 1169 not in test tuple
# index 1170 not in test tuple
# index 1171 not in test tuple
# index 1172 not in test tuple
# index 1173 not in test tuple
# index 1174 not in test tuple
# index 1175 not in test tuple
# index 1177 not in test tuple
# index 1178 not in test tuple
# index 1179 not in test tuple
# index 1180 not in test tuple
# index 1181 not in test tuple
# index 1182 not in test tuple
# index 1183 not in test tuple
# index 1184 not in test tuple
# index 1186 not in test tuple
# index 1187 not in test tuple
# index 1188 not in test tuple
# index 1189 not in test tuple
# index 1190 not in test tuple
# index 1191 not in test tuple
# index 1192 not in test tuple
# index 1193 not in test tuple
# index 1194 not in test tuple
# index 1197 not in test tuple
# index 1198 not in test tuple
# index 1199 not in test tuple
# index 1200 not in test tuple
# index 1201 not in test tuple
# index 1202 not in test tuple
# index 1203 not in test tuple
# index 1204 not in test tuple
# index 1205 not in test tuple
# index 1206 not in test tuple
# index 1208 not in test tuple
# index 1209 not in test tuple
# index 1210 not in test tuple
# index 1211 not in test tuple
# index 1212 not in test tuple
# index 1213 not in test tuple
# index 1214 not in test tuple
# index 1216 not in test tuple
# index 1217 not in test tuple
# index 1218 not in test tuple
# index 1220 not in test tuple
# index 1221 not in test tuple
# index 1222 not in test tuple
# index 1225 not in test tuple
# index 1226 not in test tuple
# index 1228 not in test tuple
# index 1229 not in test tuple
# index 1230 not in test tuple
# index 1232 not in test tuple
# index 1234 not in test tuple
# index 1235 not in test tuple
# index 1236 not in test tuple
# index 1237 not in test tuple
# index 1238 not in test tuple
# index 1239 not in test tuple
# index 1240 not in test tuple
# index 1242 not in test tuple
# index 1243 not in test tuple
# index 1244 not in test tuple
# index 1245 not in test tuple
# index 1246 not in test tuple
# index 1247 not in test tuple
# index 1248 not in test tuple
# index 1250 not in test tuple
# index 1251 not in test tuple
# index 1252 not in test tuple
# index 1253 not in test tuple
# index 1254 not in test tuple
# index 1255 not in test tuple
# index 1256 not in test tuple
# index 1257 not in test tuple
# index 1258 not in test tuple
# index 1259 not in test tuple
# index 1260 not in test tuple
# index 1261 not in test tuple
# index 1262 not in test tuple
# index 1263 not in test tuple
# index 1264 not in test tuple
# index 1265 not in test tuple
# index 1266 not in test tuple
# index 1267 not in test tuple
# index 1268 not in test tuple
# index 1271 not in test tuple
# index 1273 not in test tuple
# index 1274 not in test tuple
# index 1275 not in test tuple
# index 1276 not in test tuple
# index 1277 not in test tuple
# index 1278 not in test tuple
# index 1279 not in test tuple
# index 1280 not in test tuple
# index 1281 not in test tuple
# index 1282 not in test tuple
# index 1284 not in test tuple
# index 1285 not in test tuple
# index 1286 not in test tuple
# index 1287 not in test tuple
# index 1288 not in test tuple
# index 1289 not in test tuple
# index 1290 not in test tuple
# index 1291 not in test tuple
# index 1292 not in test tuple
# index 1293 not in test tuple
# index 1294 not in test tuple
# index 1295 not in test tuple
# index 1296 not in test tuple
# index 1297 not in test tuple
# index 1298 not in test tuple
# index 1299 not in test tuple
# index 1300 not in test tuple
# index 1301 not in test tuple
# index 1302 not in test tuple
# index 1304 not in test tuple
# index 1306 not in test tuple
# index 1307 not in test tuple
# index 1308 not in test tuple
# index 1310 not in test tuple
# index 1311 not in test tuple
# index 1312 not in test tuple
# index 1313 not in test tuple
# index 1314 not in test tuple
# index 1315 not in test tuple
# index 1316 not in test tuple
# index 1317 not in test tuple
# index 1318 not in test tuple
# index 1319 not in test tuple
# index 1320 not in test tuple
# index 1322 not in test tuple
# index 1323 not in test tuple
# index 1324 not in test tuple
# index 1325 not in test tuple
# index 1326 not in test tuple
# index 1327 not in test tuple
# index 1328 not in test tuple
# index 1330 not in test tuple
# index 1331 not in test tuple
# index 1332 not in test tuple
# index 1334 not in test tuple
# index 1335 not in test tuple
# index 1336 not in test tuple
# index 1337 not in test tuple
# index 1338 not in test tuple
# index 1339 not in test tuple
# index 1341 not in test tuple
# index 1343 not in test tuple
# index 1344 not in test tuple
# index 1345 not in test tuple
# index 1346 not in test tuple
# index 1347 not in test tuple
# index 1348 not in test tuple
# index 1349 not in test tuple
# index 1350 not in test tuple
# index 1351 not in test tuple
# index 1352 not in test tuple
# index 1353 not in test tuple
# index 1354 not in test tuple
# index 1355 not in test tuple
# index 1356 not in test tuple
# index 1357 not in test tuple
# index 1360 not in test tuple
# index 1361 not in test tuple
# index 1362 not in test tuple
# index 1363 not in test tuple
# index 1364 not in test tuple
# index 1366 not in test tuple
# index 1367 not in test tuple
# index 1368 not in test tuple
# index 1370 not in test tuple
# index 1371 not in test tuple
# index 1372 not in test tuple
# index 1373 not in test tuple
# index 1375 not in test tuple
# index 1376 not in test tuple
# index 1377 not in test tuple
# index 1378 not in test tuple
# index 1379 not in test tuple
# index 1380 not in test tuple
# index 1381 not in test tuple
# index 1382 not in test tuple
# index 1383 not in test tuple
# index 1384 not in test tuple
# index 1385 not in test tuple
# index 1386 not in test tuple
# index 1387 not in test tuple
# index 1388 not in test tuple
# index 1390 not in test tuple
# index 1391 not in test tuple
# index 1392 not in test tuple
# index 1393 not in test tuple
# index 1394 not in test tuple
# index 1395 not in test tuple
# index 1396 not in test tuple
# index 1397 not in test tuple
# index 1398 not in test tuple
# index 1399 not in test tuple
# index 1400 not in test tuple
# index 1401 not in test tuple
# index 1402 not in test tuple
# index 1403 not in test tuple
# index 1404 not in test tuple
# index 1405 not in test tuple
# index 1406 not in test tuple
# index 1407 not in test tuple
# index 1408 not in test tuple
# index 1409 not in test tuple
# index 1410 not in test tuple
# index 1411 not in test tuple
# index 1412 not in test tuple
# index 1414 not in test tuple
# index 1415 not in test tuple
# index 1417 not in test tuple
# index 1418 not in test tuple
# index 1419 not in test tuple
# index 1420 not in test tuple
# index 1422 not in test tuple
# index 1423 not in test tuple
# index 1424 not in test tuple
# index 1425 not in test tuple
# index 1426 not in test tuple
# index 1427 not in test tuple
# index 1428 not in test tuple
# index 1429 not in test tuple
# index 1430 not in test tuple
# index 1431 not in test tuple
# index 1432 not in test tuple
# index 1433 not in test tuple
# index 1435 not in test tuple
# index 1436 not in test tuple
# index 1437 not in test tuple
# index 1438 not in test tuple
# index 1439 not in test tuple
# index 1440 not in test tuple
# index 1441 not in test tuple
# index 1442 not in test tuple
# index 1443 not in test tuple
# index 1444 not in test tuple
# index 1445 not in test tuple
# index 1447 not in test tuple
# index 1448 not in test tuple
# index 1449 not in test tuple
# index 1450 not in test tuple
# index 1451 not in test tuple
# index 1452 not in test tuple
# index 1453 not in test tuple
# index 1455 not in test tuple
# index 1456 not in test tuple
# index 1457 not in test tuple
# index 1458 not in test tuple
# index 1459 not in test tuple
# index 1460 not in test tuple
# index 1461 not in test tuple
# index 1462 not in test tuple
# index 1463 not in test tuple
# index 1465 not in test tuple
# index 1466 not in test tuple
# index 1467 not in test tuple
# index 1469 not in test tuple
# index 1470 not in test tuple
# index 1471 not in test tuple
# index 1472 not in test tuple
# index 1473 not in test tuple
# index 1474 not in test tuple
# index 1476 not in test tuple
# index 1477 not in test tuple
# index 1478 not in test tuple
# index 1479 not in test tuple
# index 1480 not in test tuple
# index 1481 not in test tuple
# index 1482 not in test tuple
# index 1483 not in test tuple
# index 1484 not in test tuple
# index 1485 not in test tuple
# index 1486 not in test tuple
# index 1487 not in test tuple
# index 1488 not in test tuple
# index 1489 not in test tuple
# index 1490 not in test tuple
# index 1492 not in test tuple
# index 1493 not in test tuple
# index 1494 not in test tuple
# index 1495 not in test tuple
# index 1496 not in test tuple
# index 1497 not in test tuple
# index 1498 not in test tuple
# index 1499 not in test tuple
# index 1501 not in test tuple
# index 1502 not in test tuple
# index 1503 not in test tuple
# index 1504 not in test tuple
# index 1505 not in test tuple
# index 1506 not in test tuple
# index 1507 not in test tuple
# index 1508 not in test tuple
# index 1509 not in test tuple
# index 1510 not in test tuple
# index 1511 not in test tuple
# index 1512 not in test tuple
# index 1513 not in test tuple
# index 1514 not in test tuple
# index 1515 not in test tuple
# index 1516 not in test tuple
# index 1517 not in test tuple
# index 1518 not in test tuple
# index 1521 not in test tuple
# index 1522 not in test tuple
# index 1523 not in test tuple
# index 1524 not in test tuple
# index 1525 not in test tuple
# index 1527 not in test tuple
# index 1528 not in test tuple
# index 1529 not in test tuple
# index 1530 not in test tuple
# index 1531 not in test tuple
# index 1532 not in test tuple
# index 1533 not in test tuple
# index 1534 not in test tuple
# index 1535 not in test tuple
# index 1536 not in test tuple
# index 1539 not in test tuple
# index 1540 not in test tuple
# index 1541 not in test tuple
# index 1542 not in test tuple
# index 1543 not in test tuple
# index 1544 not in test tuple
# index 1545 not in test tuple
# index 1546 not in test tuple
# index 1548 not in test tuple
# index 1549 not in test tuple
# index 1550 not in test tuple
# index 1551 not in test tuple
# index 1552 not in test tuple
# index 1553 not in test tuple
# index 1554 not in test tuple
# index 1555 not in test tuple
# index 1556 not in test tuple
# index 1558 not in test tuple
# index 1559 not in test tuple
# index 1560 not in test tuple
# index 1561 not in test tuple
# index 1562 not in test tuple
# index 1563 not in test tuple
# index 1564 not in test tuple
# index 1565 not in test tuple
# index 1567 not in test tuple
# index 1568 not in test tuple
# index 1569 not in test tuple
# index 1570 not in test tuple
# index 1572 not in test tuple
# index 1573 not in test tuple
# index 1574 not in test tuple
# index 1575 not in test tuple
# index 1576 not in test tuple
# index 1577 not in test tuple
# index 1578 not in test tuple
# index 1581 not in test tuple
# index 1582 not in test tuple
# index 1583 not in test tuple
# index 1584 not in test tuple
# index 1585 not in test tuple
# index 1586 not in test tuple
# index 1587 not in test tuple
# index 1588 not in test tuple
# index 1589 not in test tuple
# index 1590 not in test tuple
# index 1593 not in test tuple
# index 1595 not in test tuple
# index 1599 not in test tuple
# index 1600 not in test tuple
# index 1601 not in test tuple
# index 1602 not in test tuple
# index 1603 not in test tuple
# index 1604 not in test tuple
# index 1605 not in test tuple
# index 1606 not in test tuple
# index 1607 not in test tuple
# index 1608 not in test tuple
# index 1609 not in test tuple
# index 1610 not in test tuple
# index 1611 not in test tuple
# index 1612 not in test tuple
# index 1615 not in test tuple
# index 1616 not in test tuple
# index 1617 not in test tuple
# index 1618 not in test tuple
# index 1619 not in test tuple
# index 1620 not in test tuple
# index 1621 not in test tuple
# index 1622 not in test tuple
# index 1623 not in test tuple
# index 1624 not in test tuple
# index 1625 not in test tuple
# index 1626 not in test tuple
# index 1627 not in test tuple
# index 1628 not in test tuple
# index 1629 not in test tuple
# index 1630 not in test tuple
# index 1631 not in test tuple
# index 1632 not in test tuple
# index 1633 not in test tuple
# index 1634 not in test tuple
# index 1635 not in test tuple
# index 1636 not in test tuple
# index 1637 not in test tuple
# index 1638 not in test tuple
# index 1639 not in test tuple
# index 1641 not in test tuple
# index 1643 not in test tuple
# index 1644 not in test tuple
# index 1646 not in test tuple
# index 1647 not in test tuple
# index 1649 not in test tuple
# index 1650 not in test tuple
# index 1651 not in test tuple
# index 1652 not in test tuple
# index 1653 not in test tuple
# index 1654 not in test tuple
# index 1656 not in test tuple
# index 1657 not in test tuple
# index 1658 not in test tuple
# index 1659 not in test tuple
# index 1660 not in test tuple
# index 1661 not in test tuple
# index 1663 not in test tuple
# index 1664 not in test tuple
# index 1665 not in test tuple
# index 1666 not in test tuple
# index 1667 not in test tuple
# index 1668 not in test tuple
# index 1669 not in test tuple
# index 1670 not in test tuple
# index 1671 not in test tuple
# index 1672 not in test tuple
# index 1673 not in test tuple
# index 1674 not in test tuple
# index 1675 not in test tuple
# index 1678 not in test tuple
# index 1679 not in test tuple
# index 1682 not in test tuple
# index 1683 not in test tuple
# index 1684 not in test tuple
# index 1685 not in test tuple
# index 1686 not in test tuple
# index 1687 not in test tuple
# index 1688 not in test tuple
# index 1689 not in test tuple
# index 1690 not in test tuple
# index 1691 not in test tuple
# index 1692 not in test tuple
# index 1693 not in test tuple
# index 1694 not in test tuple
# index 1696 not in test tuple
# index 1697 not in test tuple
# index 1698 not in test tuple
# index 1699 not in test tuple
# index 1701 not in test tuple
# index 1702 not in test tuple
# index 1703 not in test tuple
# index 1704 not in test tuple
# index 1705 not in test tuple
# index 1706 not in test tuple
# index 1707 not in test tuple
# index 1708 not in test tuple
# index 1709 not in test tuple
# index 1710 not in test tuple
# index 1711 not in test tuple
# index 1712 not in test tuple
# index 1713 not in test tuple
# index 1714 not in test tuple
# index 1715 not in test tuple
# index 1717 not in test tuple
# index 1718 not in test tuple
# index 1720 not in test tuple
# index 1721 not in test tuple
# index 1722 not in test tuple
# index 1723 not in test tuple
# index 1724 not in test tuple
# index 1725 not in test tuple
# index 1726 not in test tuple
# index 1727 not in test tuple
# index 1728 not in test tuple
# index 1729 not in test tuple
# index 1730 not in test tuple
# index 1731 not in test tuple
# index 1732 not in test tuple
# index 1733 not in test tuple
# index 1734 not in test tuple
# index 1736 not in test tuple
# index 1737 not in test tuple
# index 1738 not in test tuple
# index 1739 not in test tuple
# index 1740 not in test tuple
# index 1741 not in test tuple
# index 1743 not in test tuple
# index 1744 not in test tuple
# index 1745 not in test tuple
# index 1746 not in test tuple
# index 1747 not in test tuple
# index 1749 not in test tuple
# index 1750 not in test tuple
# index 1751 not in test tuple
# index 1752 not in test tuple
# index 1753 not in test tuple
# index 1754 not in test tuple
# index 1755 not in test tuple
# index 1756 not in test tuple
# index 1757 not in test tuple
# index 1758 not in test tuple
# index 1759 not in test tuple
# index 1760 not in test tuple
# index 1761 not in test tuple
# index 1762 not in test tuple
# index 1764 not in test tuple
# index 1765 not in test tuple
# index 1766 not in test tuple
# index 1767 not in test tuple
# index 1768 not in test tuple
# index 1769 not in test tuple
# index 1770 not in test tuple
# index 1772 not in test tuple
# index 1773 not in test tuple
# index 1774 not in test tuple
# index 1775 not in test tuple
# index 1776 not in test tuple
# index 1777 not in test tuple
# index 1778 not in test tuple
# index 1779 not in test tuple
# index 1780 not in test tuple
# index 1781 not in test tuple
# index 1782 not in test tuple
# index 1783 not in test tuple
# index 1784 not in test tuple
# index 1786 not in test tuple
# index 1787 not in test tuple
# index 1788 not in test tuple
# index 1789 not in test tuple
# index 1790 not in test tuple
# index 1792 not in test tuple
# index 1793 not in test tuple
# index 1794 not in test tuple
# index 1795 not in test tuple
# index 1796 not in test tuple
# index 1799 not in test tuple
# index 1800 not in test tuple
# index 1801 not in test tuple
# index 1802 not in test tuple
# index 1803 not in test tuple
# index 1804 not in test tuple
# index 1805 not in test tuple
# index 1806 not in test tuple
# index 1807 not in test tuple
# index 1808 not in test tuple
# index 1809 not in test tuple
# index 1810 not in test tuple
# index 1811 not in test tuple
# index 1812 not in test tuple
# index 1813 not in test tuple
# index 1814 not in test tuple
# index 1815 not in test tuple
# index 1816 not in test tuple
# index 1817 not in test tuple
# index 1818 not in test tuple
# index 1819 not in test tuple
# index 1820 not in test tuple
# index 1821 not in test tuple
# index 1822 not in test tuple
# index 1823 not in test tuple
# index 1824 not in test tuple
# index 1825 not in test tuple
# index 1826 not in test tuple
# index 1827 not in test tuple
# index 1828 not in test tuple
# index 1829 not in test tuple
# index 1831 not in test tuple
# index 1833 not in test tuple
# index 1834 not in test tuple
# index 1836 not in test tuple
# index 1837 not in test tuple
# index 1838 not in test tuple
# index 1839 not in test tuple
# index 1840 not in test tuple
# index 1841 not in test tuple
# index 1842 not in test tuple
# index 1843 not in test tuple
# index 1845 not in test tuple
# index 1846 not in test tuple
# index 1847 not in test tuple
# index 1848 not in test tuple
# index 1849 not in test tuple
# index 1850 not in test tuple
# index 1851 not in test tuple
# index 1852 not in test tuple
# index 1853 not in test tuple
# index 1854 not in test tuple
# index 1855 not in test tuple
# index 1856 not in test tuple
# index 1857 not in test tuple
# index 1858 not in test tuple
# index 1859 not in test tuple
# index 1861 not in test tuple
# index 1862 not in test tuple
# index 1863 not in test tuple
# index 1864 not in test tuple
# index 1865 not in test tuple
# index 1867 not in test tuple
# index 1868 not in test tuple
# index 1869 not in test tuple
# index 1871 not in test tuple
# index 1872 not in test tuple
# index 1873 not in test tuple
# index 1874 not in test tuple
# index 1875 not in test tuple
# index 1876 not in test tuple
# index 1877 not in test tuple
# index 1879 not in test tuple
# index 1881 not in test tuple
# index 1882 not in test tuple
# index 1883 not in test tuple
# index 1884 not in test tuple
# index 1885 not in test tuple
# index 1886 not in test tuple
# index 1887 not in test tuple
# index 1888 not in test tuple
# index 1889 not in test tuple
# index 1890 not in test tuple
# index 1891 not in test tuple
# index 1892 not in test tuple
# index 1894 not in test tuple
# index 1896 not in test tuple
# index 1898 not in test tuple
# index 1899 not in test tuple
# index 1900 not in test tuple
# index 1901 not in test tuple
# index 1902 not in test tuple
# index 1904 not in test tuple
# index 1905 not in test tuple
# index 1906 not in test tuple
# index 1907 not in test tuple
# index 1908 not in test tuple
# index 1909 not in test tuple
# index 1910 not in test tuple
# index 1911 not in test tuple
# index 1912 not in test tuple
# index 1913 not in test tuple
# index 1915 not in test tuple
# index 1916 not in test tuple
# index 1917 not in test tuple
# index 1918 not in test tuple
# index 1919 not in test tuple
# index 1921 not in test tuple
# index 1922 not in test tuple
# index 1923 not in test tuple
# index 1925 not in test tuple
# index 1926 not in test tuple
# index 1927 not in test tuple
# index 1928 not in test tuple
# index 1929 not in test tuple
# index 1930 not in test tuple
# index 1931 not in test tuple
# index 1932 not in test tuple
# ...
# index 2684 not in test tuple
# index 2685 not in test tuple
# index 2686 not in test tuple
# index 2687 not in test tuple
# index 2688 not in test tuple
# index 2689 not in test tuple
# index 2690 not in test tuple
# index 2692 not in test tuple
# index 2694 not in test tuple
# index 2695 not in test tuple
# index 2696 not in test tuple
# index 2697 not in test tuple
# index 2698 not in test tuple
# index 2700 not in test tuple
# index 2702 not in test tuple
# index 2703 not in test tuple
# index 2704 not in test tuple
# index 2706 not in test tuple
# index 2708 not in test tuple
# index 2709 not in test tuple
# index 2710 not in test tuple
# index 2711 not in test tuple
# index 2712 not in test tuple
# index 2713 not in test tuple
# index 2714 not in test tuple
# index 2715 not in test tuple
# index 2716 not in test tuple
# index 2717 not in test tuple
# index 2719 not in test tuple
# index 2720 not in test tuple
# index 2721 not in test tuple
# index 2722 not in test tuple
# index 2723 not in test tuple
# index 2724 not in test tuple
# index 2725 not in test tuple
# index 2726 not in test tuple
# index 2727 not in test tuple
# index 2728 not in test tuple
# index 2729 not in test tuple
# index 2730 not in test tuple
# index 2731 not in test tuple
# index 2732 not in test tuple
# index 2733 not in test tuple
# index 2734 not in test tuple
# index 2735 not in test tuple
# index 2737 not in test tuple
# index 2738 not in test tuple
# index 2739 not in test tuple
# index 2740 not in test tuple
# index 2741 not in test tuple
# index 2742 not in test tuple
# index 2743 not in test tuple
# index 2744 not in test tuple
# index 2745 not in test tuple
# index 2746 not in test tuple
# index 2747 not in test tuple
# index 2749 not in test tuple
# index 2750 not in test tuple
# index 2751 not in test tuple
# index 2752 not in test tuple
# index 2753 not in test tuple
# index 2754 not in test tuple
# index 2755 not in test tuple
# index 2756 not in test tuple
# index 2757 not in test tuple
# index 2758 not in test tuple
# index 2759 not in test tuple
# index 2760 not in test tuple
# index 2761 not in test tuple
# index 2762 not in test tuple
# index 2764 not in test tuple
# index 2765 not in test tuple
# index 2766 not in test tuple
# index 2767 not in test tuple
# index 2768 not in test tuple
# index 2769 not in test tuple
# index 2770 not in test tuple
# index 2771 not in test tuple
# index 2772 not in test tuple
# index 2773 not in test tuple
# index 2774 not in test tuple
# index 2775 not in test tuple
# index 2777 not in test tuple
# index 2778 not in test tuple
# index 2779 not in test tuple
# index 2780 not in test tuple
# index 2781 not in test tuple
# index 2782 not in test tuple
# index 2783 not in test tuple
# index 2784 not in test tuple
# index 2785 not in test tuple
# index 2786 not in test tuple
# index 2787 not in test tuple
# index 2789 not in test tuple
# index 2790 not in test tuple
# index 2792 not in test tuple
# index 2793 not in test tuple
# index 2794 not in test tuple
# index 2795 not in test tuple
# index 2796 not in test tuple
# index 2797 not in test tuple
# index 2798 not in test tuple
# index 2799 not in test tuple
# index 2800 not in test tuple
# index 2801 not in test tuple
# index 2804 not in test tuple
# index 2805 not in test tuple
# index 2806 not in test tuple
# index 2807 not in test tuple
# index 2808 not in test tuple
# index 2809 not in test tuple
# index 2810 not in test tuple
# index 2811 not in test tuple
# index 2812 not in test tuple
# index 2813 not in test tuple
# index 2814 not in test tuple
# index 2815 not in test tuple
# index 2816 not in test tuple
# index 2817 not in test tuple
# index 2818 not in test tuple
# index 2819 not in test tuple
# index 2820 not in test tuple
# index 2821 not in test tuple
# index 2822 not in test tuple
# index 2823 not in test tuple
# index 2824 not in test tuple
# index 2825 not in test tuple
# index 2826 not in test tuple
# index 2827 not in test tuple
# index 2829 not in test tuple
# index 2830 not in test tuple
# index 2831 not in test tuple
# index 2832 not in test tuple
# index 2833 not in test tuple
# index 2834 not in test tuple
# index 2835 not in test tuple
# index 2836 not in test tuple
# index 2837 not in test tuple
# index 2838 not in test tuple
# index 2839 not in test tuple
# index 2840 not in test tuple
# index 2841 not in test tuple
# index 2842 not in test tuple
# index 2843 not in test tuple
# index 2844 not in test tuple
# index 2845 not in test tuple
# index 2846 not in test tuple
# index 2847 not in test tuple
# index 2848 not in test tuple
# index 2849 not in test tuple
# index 2850 not in test tuple
# index 2852 not in test tuple
# index 2853 not in test tuple
# index 2855 not in test tuple
# index 2856 not in test tuple
# index 2857 not in test tuple
# index 2858 not in test tuple
# index 2859 not in test tuple
# index 2860 not in test tuple
# index 2861 not in test tuple
# index 2862 not in test tuple
# index 2863 not in test tuple
# index 2864 not in test tuple
# index 2865 not in test tuple
# index 2866 not in test tuple
# index 2867 not in test tuple
# index 2868 not in test tuple
# index 2869 not in test tuple
# index 2870 not in test tuple
# index 2872 not in test tuple
# index 2873 not in test tuple
# index 2875 not in test tuple
# index 2876 not in test tuple
# index 2877 not in test tuple
# index 2878 not in test tuple
# index 2879 not in test tuple
# index 2880 not in test tuple
# index 2881 not in test tuple
# index 2882 not in test tuple
# index 2883 not in test tuple
# index 2885 not in test tuple
# index 2886 not in test tuple
# index 2887 not in test tuple
# index 2888 not in test tuple
# index 2889 not in test tuple
# index 2890 not in test tuple
# index 2891 not in test tuple
# index 2892 not in test tuple
# index 2893 not in test tuple
# index 2895 not in test tuple
# index 2896 not in test tuple
# index 2897 not in test tuple
# index 2898 not in test tuple
# index 2899 not in test tuple
# index 2901 not in test tuple
# index 2903 not in test tuple
# index 2904 not in test tuple
# index 2905 not in test tuple
# index 2907 not in test tuple
# index 2908 not in test tuple
# index 2909 not in test tuple
# index 2910 not in test tuple
# index 2911 not in test tuple
# index 2912 not in test tuple
# index 2913 not in test tuple
# index 2914 not in test tuple
# index 2915 not in test tuple
# index 2916 not in test tuple
# index 2917 not in test tuple
# index 2918 not in test tuple
# index 2919 not in test tuple
# index 2920 not in test tuple
# index 2921 not in test tuple
# index 2922 not in test tuple
# index 2923 not in test tuple
# index 2924 not in test tuple
# index 2925 not in test tuple
# index 2926 not in test tuple
# index 2927 not in test tuple
# index 2928 not in test tuple
# index 2929 not in test tuple
# index 2930 not in test tuple
# index 2931 not in test tuple
# index 2932 not in test tuple
# index 2933 not in test tuple
# index 2934 not in test tuple
# index 2935 not in test tuple
# index 2936 not in test tuple
# index 2937 not in test tuple
# index 2938 not in test tuple
# index 2939 not in test tuple
# index 2940 not in test tuple
# index 2941 not in test tuple
# index 2942 not in test tuple
# index 2943 not in test tuple
# index 2944 not in test tuple
# index 2945 not in test tuple
# index 2946 not in test tuple
# index 2947 not in test tuple
# index 2948 not in test tuple
# index 2949 not in test tuple
# index 2950 not in test tuple
# index 2952 not in test tuple
# index 2954 not in test tuple
# index 2955 not in test tuple
# index 2956 not in test tuple
# index 2957 not in test tuple
# index 2958 not in test tuple
# index 2959 not in test tuple
# index 2960 not in test tuple
# index 2961 not in test tuple
# index 2962 not in test tuple
# index 2963 not in test tuple
# index 2964 not in test tuple
# index 2965 not in test tuple
# index 2966 not in test tuple
# index 2967 not in test tuple
# index 2968 not in test tuple
# index 2969 not in test tuple
# index 2970 not in test tuple
# index 2971 not in test tuple
# index 2972 not in test tuple
# index 2973 not in test tuple
# index 2974 not in test tuple
# index 2975 not in test tuple
# index 2976 not in test tuple
# index 2977 not in test tuple
# index 2978 not in test tuple
# index 2979 not in test tuple
# index 2980 not in test tuple
# index 2981 not in test tuple
# index 2982 not in test tuple
# index 2983 not in test tuple
# index 2984 not in test tuple
# index 2985 not in test tuple
# index 2986 not in test tuple
# index 2987 not in test tuple
# index 2988 not in test tuple
# index 2989 not in test tuple
# index 2990 not in test tuple
# index 2991 not in test tuple
# index 2992 not in test tuple
# index 2993 not in test tuple
# index 2994 not in test tuple
# index 2995 not in test tuple
# index 2996 not in test tuple
# index 2997 not in test tuple
# index 2998 not in test tuple
# index 2999 not in test tuple
# index 3001 not in test tuple
# index 3002 not in test tuple
# index 3003 not in test tuple
# index 3005 not in test tuple
# index 3006 not in test tuple
# index 3007 not in test tuple
# index 3008 not in test tuple
# index 3009 not in test tuple
# index 3010 not in test tuple
# index 3011 not in test tuple
# index 3012 not in test tuple
# index 3013 not in test tuple
# index 3014 not in test tuple
# index 3015 not in test tuple
# index 3016 not in test tuple
# index 3017 not in test tuple
# index 3018 not in test tuple
# index 3019 not in test tuple
# index 3020 not in test tuple
# index 3021 not in test tuple
# index 3022 not in test tuple
# index 3023 not in test tuple
# index 3024 not in test tuple
# index 3027 not in test tuple
# index 3028 not in test tuple
# index 3029 not in test tuple
# index 3030 not in test tuple
# index 3031 not in test tuple
# index 3033 not in test tuple
# index 3035 not in test tuple
# index 3037 not in test tuple
# index 3039 not in test tuple
# index 3041 not in test tuple
# index 3042 not in test tuple
# index 3043 not in test tuple
# index 3044 not in test tuple
# index 3045 not in test tuple
# index 3046 not in test tuple
# index 3047 not in test tuple
# index 3048 not in test tuple
# index 3049 not in test tuple
# index 3050 not in test tuple
# index 3051 not in test tuple
# index 3052 not in test tuple
# index 3053 not in test tuple
# index 3054 not in test tuple
# index 3056 not in test tuple
# index 3057 not in test tuple
# index 3058 not in test tuple
# index 3060 not in test tuple
# index 3062 not in test tuple
# index 3063 not in test tuple
# index 3064 not in test tuple
# index 3065 not in test tuple
# index 3066 not in test tuple
# index 3067 not in test tuple
# index 3068 not in test tuple
# index 3069 not in test tuple
# index 3070 not in test tuple
# index 3071 not in test tuple
# index 3072 not in test tuple
# index 3073 not in test tuple
# index 3074 not in test tuple
# index 3075 not in test tuple
# index 3076 not in test tuple
# index 3077 not in test tuple
# index 3078 not in test tuple
# index 3079 not in test tuple
# index 3080 not in test tuple
# index 3081 not in test tuple
# index 3082 not in test tuple
# index 3083 not in test tuple
# index 3084 not in test tuple
# index 3085 not in test tuple
# index 3086 not in test tuple
# index 3087 not in test tuple
# index 3088 not in test tuple
# index 3089 not in test tuple
# index 3090 not in test tuple
# index 3092 not in test tuple
# index 3094 not in test tuple
# index 3096 not in test tuple
# index 3098 not in test tuple
# index 3099 not in test tuple
# index 3100 not in test tuple
# index 3101 not in test tuple
# index 3102 not in test tuple
# index 3103 not in test tuple
# index 3104 not in test tuple
# index 3106 not in test tuple
# index 3107 not in test tuple
# index 3108 not in test tuple
# index 3109 not in test tuple
# index 3110 not in test tuple
# index 3111 not in test tuple
# index 3113 not in test tuple
# index 3114 not in test tuple
# index 3115 not in test tuple
# index 3116 not in test tuple
# index 3117 not in test tuple
# index 3118 not in test tuple
# index 3119 not in test tuple
# index 3120 not in test tuple
# index 3121 not in test tuple
# index 3122 not in test tuple
# index 3123 not in test tuple
# index 3125 not in test tuple
# index 3126 not in test tuple
# index 3127 not in test tuple
# index 3128 not in test tuple
# index 3129 not in test tuple
# index 3131 not in test tuple
# index 3132 not in test tuple
# index 3133 not in test tuple
# index 3134 not in test tuple
# index 3136 not in test tuple
# index 3137 not in test tuple
# index 3138 not in test tuple
# index 3139 not in test tuple
# index 3140 not in test tuple
# index 3142 not in test tuple
# index 3143 not in test tuple
# index 3144 not in test tuple
# index 3145 not in test tuple
# index 3146 not in test tuple
# index 3147 not in test tuple
# index 3148 not in test tuple
# index 3149 not in test tuple
# index 3150 not in test tuple
# index 3151 not in test tuple
# index 3152 not in test tuple
# index 3153 not in test tuple
# index 3154 not in test tuple
# index 3155 not in test tuple
# index 3156 not in test tuple
# index 3157 not in test tuple
# index 3158 not in test tuple
# index 3159 not in test tuple
# index 3160 not in test tuple
# index 3161 not in test tuple
# index 3162 not in test tuple
# index 3163 not in test tuple
# index 3164 not in test tuple
# index 3165 not in test tuple
# index 3166 not in test tuple
# index 3167 not in test tuple
# index 3168 not in test tuple
# index 3169 not in test tuple
# index 3170 not in test tuple
# index 3171 not in test tuple
# index 3172 not in test tuple
# index 3173 not in test tuple
# index 3174 not in test tuple
# index 3175 not in test tuple
# index 3178 not in test tuple
# index 3179 not in test tuple
# index 3180 not in test tuple
# index 3181 not in test tuple
# index 3182 not in test tuple
# index 3183 not in test tuple
# index 3184 not in test tuple
# index 3185 not in test tuple
# index 3186 not in test tuple
# index 3187 not in test tuple
# index 3189 not in test tuple
# index 3190 not in test tuple
# index 3191 not in test tuple
# index 3192 not in test tuple
# index 3193 not in test tuple
# index 3194 not in test tuple
# index 3195 not in test tuple
# index 3197 not in test tuple
# index 3198 not in test tuple
# index 3199 not in test tuple
# index 3200 not in test tuple
# index 3201 not in test tuple
# index 3202 not in test tuple
# index 3203 not in test tuple
# index 3204 not in test tuple
# index 3205 not in test tuple
# index 3206 not in test tuple
# index 3207 not in test tuple
# index 3208 not in test tuple
# index 3209 not in test tuple
# index 3211 not in test tuple
# index 3212 not in test tuple
# index 3213 not in test tuple
# index 3214 not in test tuple
# index 3215 not in test tuple
# index 3216 not in test tuple
# index 3217 not in test tuple
# index 3218 not in test tuple
# index 3220 not in test tuple
# index 3221 not in test tuple
# index 3222 not in test tuple
# index 3224 not in test tuple
# index 3225 not in test tuple
# index 3226 not in test tuple
# index 3227 not in test tuple
# index 3229 not in test tuple
# index 3230 not in test tuple
# index 3231 not in test tuple
# index 3232 not in test tuple
# index 3233 not in test tuple
# index 3235 not in test tuple
# index 3236 not in test tuple
# index 3237 not in test tuple
# index 3238 not in test tuple
# index 3239 not in test tuple
# index 3240 not in test tuple
# index 3241 not in test tuple
# index 3242 not in test tuple
# index 3243 not in test tuple
# index 3244 not in test tuple
# index 3245 not in test tuple
# index 3246 not in test tuple
# index 3247 not in test tuple
# index 3248 not in test tuple
# index 3249 not in test tuple
# index 3250 not in test tuple
# index 3251 not in test tuple
# index 3252 not in test tuple
# index 3254 not in test tuple
# index 3255 not in test tuple
# index 3256 not in test tuple
# index 3257 not in test tuple
# index 3258 not in test tuple
# index 3259 not in test tuple
# index 3260 not in test tuple
# index 3261 not in test tuple
# index 3262 not in test tuple
# index 3263 not in test tuple
# index 3264 not in test tuple
# index 3265 not in test tuple
# index 3266 not in test tuple
# index 3268 not in test tuple
# index 3269 not in test tuple
# index 3270 not in test tuple
# index 3272 not in test tuple
# index 3274 not in test tuple
# index 3275 not in test tuple
# index 3277 not in test tuple
# index 3279 not in test tuple
# index 3280 not in test tuple
# index 3281 not in test tuple
# index 3282 not in test tuple
# index 3283 not in test tuple
# index 3284 not in test tuple
# index 3285 not in test tuple
# index 3286 not in test tuple
# index 3287 not in test tuple
# index 3288 not in test tuple
# index 3289 not in test tuple
# index 3290 not in test tuple
# index 3291 not in test tuple
# index 3292 not in test tuple
# index 3293 not in test tuple
# index 3295 not in test tuple
# index 3296 not in test tuple
# index 3297 not in test tuple
# index 3298 not in test tuple
# index 3299 not in test tuple

# %%
populate_directory(X_val, y_val, 'val')
# Out:
# index 0 not in val tuple
# index 2 not in val tuple
# index 3 not in val tuple
# index 4 not in val tuple
# index 5 not in val tuple
# index 6 not in val tuple
# index 7 not in val tuple
# index 8 not in val tuple
# index 9 not in val tuple
# index 10 not in val tuple
# index 11 not in val tuple
# index 12 not in val tuple
# index 13 not in val tuple
# index 14 not in val tuple
# index 15 not in val tuple
# index 16 not in val tuple
# index 17 not in val tuple
# index 18 not in val tuple
# index 19 not in val tuple
# index 20 not in val tuple
# index 22 not in val tuple
# index 23 not in val tuple
# index 24 not in val tuple
# index 25 not in val tuple
# index 27 not in val tuple
# index 28 not in val tuple
# index 29 not in val tuple
# index 30 not in val tuple
# index 31 not in val tuple
# index 32 not in val tuple
# index 33 not in val tuple
# index 34 not in val tuple
# index 35 not in val tuple
# index 36 not in val tuple
# index 37 not in val tuple
# index 38 not in val tuple
# index 39 not in val tuple
# index 40 not in val tuple
# index 42 not in val tuple
# index 43 not in val tuple
# index 44 not in val tuple
# index 45 not in val tuple
# index 46 not in val tuple
# index 50 not in val tuple
# index 51 not in val tuple
# index 52 not in val tuple
# index 53 not in val tuple
# index 54 not in val tuple
# index 55 not in val tuple
# index 56 not in val tuple
# index 57 not in val tuple
# index 59 not in val tuple
# index 60 not in val tuple
# index 61 not in val tuple
# index 62 not in val tuple
# index 64 not in val tuple
# index 65 not in val tuple
# index 66 not in val tuple
# index 67 not in val tuple
# index 68 not in val tuple
# index 69 not in val tuple
# index 71 not in val tuple
# index 72 not in val tuple
# index 74 not in val tuple
# index 75 not in val tuple
# index 76 not in val tuple
# index 77 not in val tuple
# index 78 not in val tuple
# index 79 not in val tuple
# index 80 not in val tuple
# index 81 not in val tuple
# index 83 not in val tuple
# index 84 not in val tuple
# index 85 not in val tuple
# index 86 not in val tuple
# index 87 not in val tuple
# index 88 not in val tuple
# index 90 not in val tuple
# index 91 not in val tuple
# index 92 not in val tuple
# index 93 not in val tuple
# index 94 not in val tuple
# index 95 not in val tuple
# index 96 not in val tuple
# index 97 not in val tuple
# index 98 not in val tuple
# index 99 not in val tuple
# index 100 not in val tuple
# index 101 not in val tuple
# index 102 not in val tuple
# index 103 not in val tuple
# index 104 not in val tuple
# index 105 not in val tuple
# index 106 not in val tuple
# index 107 not in val tuple
# index 108 not in val tuple
# index 109 not in val tuple
# index 110 not in val tuple
# index 111 not in val tuple
# index 112 not in val tuple
# index 113 not in val tuple
# index 114 not in val tuple
# index 115 not in val tuple
# index 116 not in val tuple
# index 117 not in val tuple
# index 118 not in val tuple
# index 119 not in val tuple
# index 120 not in val tuple
# index 121 not in val tuple
# index 122 not in val tuple
# index 124 not in val tuple
# index 125 not in val tuple
# index 127 not in val tuple
# index 128 not in val tuple
# index 129 not in val tuple
# index 130 not in val tuple
# index 131 not in val tuple
# index 132 not in val tuple
# index 133 not in val tuple
# index 134 not in val tuple
# index 135 not in val tuple
# index 136 not in val tuple
# index 138 not in val tuple
# index 140 not in val tuple
# index 141 not in val tuple
# index 142 not in val tuple
# index 143 not in val tuple
# index 144 not in val tuple
# index 146 not in val tuple
# index 147 not in val tuple
# index 148 not in val tuple
# index 149 not in val tuple
# index 150 not in val tuple
# index 151 not in val tuple
# index 152 not in val tuple
# index 154 not in val tuple
# index 155 not in val tuple
# index 156 not in val tuple
# index 157 not in val tuple
# index 158 not in val tuple
# index 159 not in val tuple
# index 160 not in val tuple
# index 162 not in val tuple
# index 163 not in val tuple
# index 164 not in val tuple
# index 165 not in val tuple
# index 167 not in val tuple
# index 168 not in val tuple
# index 169 not in val tuple
# index 172 not in val tuple
# index 173 not in val tuple
# index 174 not in val tuple
# index 175 not in val tuple
# index 176 not in val tuple
# index 178 not in val tuple
# index 179 not in val tuple
# index 180 not in val tuple
# index 181 not in val tuple
# index 182 not in val tuple
# index 183 not in val tuple
# index 184 not in val tuple
# index 185 not in val tuple
# index 186 not in val tuple
# index 188 not in val tuple
# index 189 not in val tuple
# index 190 not in val tuple
# index 191 not in val tuple
# index 192 not in val tuple
# index 193 not in val tuple
# index 194 not in val tuple
# index 195 not in val tuple
# index 196 not in val tuple
# index 197 not in val tuple
# index 198 not in val tuple
# index 199 not in val tuple
# index 200 not in val tuple
# index 202 not in val tuple
# index 203 not in val tuple
# index 205 not in val tuple
# index 206 not in val tuple
# index 207 not in val tuple
# index 208 not in val tuple
# index 209 not in val tuple
# index 210 not in val tuple
# index 211 not in val tuple
# index 212 not in val tuple
# index 214 not in val tuple
# index 215 not in val tuple
# index 216 not in val tuple
# index 217 not in val tuple
# index 218 not in val tuple
# index 219 not in val tuple
# index 220 not in val tuple
# index 221 not in val tuple
# index 222 not in val tuple
# index 223 not in val tuple
# index 224 not in val tuple
# index 225 not in val tuple
# index 226 not in val tuple
# index 227 not in val tuple
# index 228 not in val tuple
# index 229 not in val tuple
# index 230 not in val tuple
# index 231 not in val tuple
# index 232 not in val tuple
# index 233 not in val tuple
# index 234 not in val tuple
# index 235 not in val tuple
# index 236 not in val tuple
# index 237 not in val tuple
# index 238 not in val tuple
# index 239 not in val tuple
# index 241 not in val tuple
# index 242 not in val tuple
# index 243 not in val tuple
# index 244 not in val tuple
# index 245 not in val tuple
# index 246 not in val tuple
# index 247 not in val tuple
# index 248 not in val tuple
# index 250 not in val tuple
# index 251 not in val tuple
# index 252 not in val tuple
# index 253 not in val tuple
# index 254 not in val tuple
# index 255 not in val tuple
# index 256 not in val tuple
# index 257 not in val tuple
# index 259 not in val tuple
# index 260 not in val tuple
# index 261 not in val tuple
# index 262 not in val tuple
# index 263 not in val tuple
# index 264 not in val tuple
# index 265 not in val tuple
# index 266 not in val tuple
# index 267 not in val tuple
# index 268 not in val tuple
# index 270 not in val tuple
# index 272 not in val tuple
# index 273 not in val tuple
# index 274 not in val tuple
# index 275 not in val tuple
# index 276 not in val tuple
# index 277 not in val tuple
# index 279 not in val tuple
# index 281 not in val tuple
# index 282 not in val tuple
# index 283 not in val tuple
# index 284 not in val tuple
# index 285 not in val tuple
# index 286 not in val tuple
# index 288 not in val tuple
# index 289 not in val tuple
# index 290 not in val tuple
# index 291 not in val tuple
# index 293 not in val tuple
# index 295 not in val tuple
# index 296 not in val tuple
# index 297 not in val tuple
# index 298 not in val tuple
# index 299 not in val tuple
# index 300 not in val tuple
# index 301 not in val tuple
# index 302 not in val tuple
# index 303 not in val tuple
# index 304 not in val tuple
# index 305 not in val tuple
# index 306 not in val tuple
# index 307 not in val tuple
# index 308 not in val tuple
# index 309 not in val tuple
# index 310 not in val tuple
# index 311 not in val tuple
# index 312 not in val tuple
# index 313 not in val tuple
# index 314 not in val tuple
# index 315 not in val tuple
# index 316 not in val tuple
# index 317 not in val tuple
# index 318 not in val tuple
# index 319 not in val tuple
# index 320 not in val tuple
# index 321 not in val tuple
# index 322 not in val tuple
# index 323 not in val tuple
# index 324 not in val tuple
# index 325 not in val tuple
# index 327 not in val tuple
# index 328 not in val tuple
# index 329 not in val tuple
# index 330 not in val tuple
# index 331 not in val tuple
# index 332 not in val tuple
# index 333 not in val tuple
# index 334 not in val tuple
# index 335 not in val tuple
# index 336 not in val tuple
# index 337 not in val tuple
# index 338 not in val tuple
# index 339 not in val tuple
# index 340 not in val tuple
# index 341 not in val tuple
# index 342 not in val tuple
# index 343 not in val tuple
# index 345 not in val tuple
# index 346 not in val tuple
# index 347 not in val tuple
# index 348 not in val tuple
# index 349 not in val tuple
# index 350 not in val tuple
# index 351 not in val tuple
# index 352 not in val tuple
# index 353 not in val tuple
# index 354 not in val tuple
# index 355 not in val tuple
# index 356 not in val tuple
# index 358 not in val tuple
# index 359 not in val tuple
# index 360 not in val tuple
# index 361 not in val tuple
# index 362 not in val tuple
# index 363 not in val tuple
# index 364 not in val tuple
# index 366 not in val tuple
# index 367 not in val tuple
# index 368 not in val tuple
# index 369 not in val tuple
# index 370 not in val tuple
# index 372 not in val tuple
# index 373 not in val tuple
# index 374 not in val tuple
# index 375 not in val tuple
# index 376 not in val tuple
# index 377 not in val tuple
# index 378 not in val tuple
# index 379 not in val tuple
# index 380 not in val tuple
# index 381 not in val tuple
# index 382 not in val tuple
# index 383 not in val tuple
# index 385 not in val tuple
# index 386 not in val tuple
# index 387 not in val tuple
# index 388 not in val tuple
# index 390 not in val tuple
# index 391 not in val tuple
# index 392 not in val tuple
# index 393 not in val tuple
# index 394 not in val tuple
# index 395 not in val tuple
# index 396 not in val tuple
# index 397 not in val tuple
# index 398 not in val tuple
# index 399 not in val tuple
# index 400 not in val tuple
# index 401 not in val tuple
# index 402 not in val tuple
# index 403 not in val tuple
# index 404 not in val tuple
# index 405 not in val tuple
# index 406 not in val tuple
# index 407 not in val tuple
# index 408 not in val tuple
# index 409 not in val tuple
# index 410 not in val tuple
# index 411 not in val tuple
# index 412 not in val tuple
# index 413 not in val tuple
# index 414 not in val tuple
# index 415 not in val tuple
# index 416 not in val tuple
# index 417 not in val tuple
# index 418 not in val tuple
# index 419 not in val tuple
# index 420 not in val tuple
# index 421 not in val tuple
# index 422 not in val tuple
# index 423 not in val tuple
# index 424 not in val tuple
# index 426 not in val tuple
# index 427 not in val tuple
# index 428 not in val tuple
# index 429 not in val tuple
# index 430 not in val tuple
# index 431 not in val tuple
# index 432 not in val tuple
# index 433 not in val tuple
# index 434 not in val tuple
# index 436 not in val tuple
# index 437 not in val tuple
# index 438 not in val tuple
# index 439 not in val tuple
# index 440 not in val tuple
# index 441 not in val tuple
# index 442 not in val tuple
# index 443 not in val tuple
# index 444 not in val tuple
# index 445 not in val tuple
# index 446 not in val tuple
# index 448 not in val tuple
# index 449 not in val tuple
# index 450 not in val tuple
# index 451 not in val tuple
# index 452 not in val tuple
# index 453 not in val tuple
# index 454 not in val tuple
# index 455 not in val tuple
# index 456 not in val tuple
# index 457 not in val tuple
# index 458 not in val tuple
# index 459 not in val tuple
# index 460 not in val tuple
# index 462 not in val tuple
# index 463 not in val tuple
# index 464 not in val tuple
# index 465 not in val tuple
# index 466 not in val tuple
# index 467 not in val tuple
# index 468 not in val tuple
# index 469 not in val tuple
# index 470 not in val tuple
# index 471 not in val tuple
# index 473 not in val tuple
# index 474 not in val tuple
# index 475 not in val tuple
# index 476 not in val tuple
# index 477 not in val tuple
# index 478 not in val tuple
# index 479 not in val tuple
# index 480 not in val tuple
# index 481 not in val tuple
# index 482 not in val tuple
# index 483 not in val tuple
# index 484 not in val tuple
# index 485 not in val tuple
# index 486 not in val tuple
# index 487 not in val tuple
# index 489 not in val tuple
# index 490 not in val tuple
# index 491 not in val tuple
# index 492 not in val tuple
# index 493 not in val tuple
# index 495 not in val tuple
# index 496 not in val tuple
# index 498 not in val tuple
# index 500 not in val tuple
# index 501 not in val tuple
# index 502 not in val tuple
# index 503 not in val tuple
# index 504 not in val tuple
# index 505 not in val tuple
# index 506 not in val tuple
# index 507 not in val tuple
# index 508 not in val tuple
# index 509 not in val tuple
# index 510 not in val tuple
# index 511 not in val tuple
# index 512 not in val tuple
# index 513 not in val tuple
# index 514 not in val tuple
# index 515 not in val tuple
# index 516 not in val tuple
# index 518 not in val tuple
# index 519 not in val tuple
# index 520 not in val tuple
# index 521 not in val tuple
# index 522 not in val tuple
# index 523 not in val tuple
# index 524 not in val tuple
# index 525 not in val tuple
# index 526 not in val tuple
# index 527 not in val tuple
# index 528 not in val tuple
# index 529 not in val tuple
# index 530 not in val tuple
# index 531 not in val tuple
# index 533 not in val tuple
# index 534 not in val tuple
# index 535 not in val tuple
# index 537 not in val tuple
# index 538 not in val tuple
# index 539 not in val tuple
# index 540 not in val tuple
# index 541 not in val tuple
# index 542 not in val tuple
# index 543 not in val tuple
# index 544 not in val tuple
# index 545 not in val tuple
# index 546 not in val tuple
# index 547 not in val tuple
# index 549 not in val tuple
# index 550 not in val tuple
# index 551 not in val tuple
# index 552 not in val tuple
# index 553 not in val tuple
# index 554 not in val tuple
# index 555 not in val tuple
# index 556 not in val tuple
# index 557 not in val tuple
# index 558 not in val tuple
# index 559 not in val tuple
# index 560 not in val tuple
# index 561 not in val tuple
# index 562 not in val tuple
# index 563 not in val tuple
# index 564 not in val tuple
# index 566 not in val tuple
# index 567 not in val tuple
# index 568 not in val tuple
# index 569 not in val tuple
# index 571 not in val tuple
# index 572 not in val tuple
# index 573 not in val tuple
# index 574 not in val tuple
# index 575 not in val tuple
# index 576 not in val tuple
# index 577 not in val tuple
# index 578 not in val tuple
# index 579 not in val tuple
# index 580 not in val tuple
# index 581 not in val tuple
# index 582 not in val tuple
# index 583 not in val tuple
# index 585 not in val tuple
# index 586 not in val tuple
# index 587 not in val tuple
# index 588 not in val tuple
# index 589 not in val tuple
# index 590 not in val tuple
# index 591 not in val tuple
# index 592 not in val tuple
# index 593 not in val tuple
# index 594 not in val tuple
# index 595 not in val tuple
# index 596 not in val tuple
# index 597 not in val tuple
# index 598 not in val tuple
# index 599 not in val tuple
# index 600 not in val tuple
# index 601 not in val tuple
# index 602 not in val tuple
# index 603 not in val tuple
# index 604 not in val tuple
# index 606 not in val tuple
# index 607 not in val tuple
# index 608 not in val tuple
# index 609 not in val tuple
# index 611 not in val tuple
# index 612 not in val tuple
# index 613 not in val tuple
# index 614 not in val tuple
# index 615 not in val tuple
# index 616 not in val tuple
# index 617 not in val tuple
# index 618 not in val tuple
# index 620 not in val tuple
# index 621 not in val tuple
# index 622 not in val tuple
# index 623 not in val tuple
# index 624 not in val tuple
# index 625 not in val tuple
# index 626 not in val tuple
# index 627 not in val tuple
# index 628 not in val tuple
# index 629 not in val tuple
# index 630 not in val tuple
# index 631 not in val tuple
# index 632 not in val tuple
# index 633 not in val tuple
# index 634 not in val tuple
# index 635 not in val tuple
# index 637 not in val tuple
# index 639 not in val tuple
# index 640 not in val tuple
# index 641 not in val tuple
# index 642 not in val tuple
# index 643 not in val tuple
# index 644 not in val tuple
# index 645 not in val tuple
# index 646 not in val tuple
# index 647 not in val tuple
# index 649 not in val tuple
# index 650 not in val tuple
# index 651 not in val tuple
# index 653 not in val tuple
# index 654 not in val tuple
# index 656 not in val tuple
# index 657 not in val tuple
# index 658 not in val tuple
# index 659 not in val tuple
# index 660 not in val tuple
# index 661 not in val tuple
# index 662 not in val tuple
# index 663 not in val tuple
# index 664 not in val tuple
# index 665 not in val tuple
# index 666 not in val tuple
# index 667 not in val tuple
# index 668 not in val tuple
# index 669 not in val tuple
# index 670 not in val tuple
# index 671 not in val tuple
# index 672 not in val tuple
# index 673 not in val tuple
# index 674 not in val tuple
# index 675 not in val tuple
# index 676 not in val tuple
# index 677 not in val tuple
# index 679 not in val tuple
# index 680 not in val tuple
# index 681 not in val tuple
# index 682 not in val tuple
# index 683 not in val tuple
# index 684 not in val tuple
# index 685 not in val tuple
# index 686 not in val tuple
# index 687 not in val tuple
# index 688 not in val tuple
# index 690 not in val tuple
# index 691 not in val tuple
# index 692 not in val tuple
# index 693 not in val tuple
# index 695 not in val tuple
# index 696 not in val tuple
# index 698 not in val tuple
# index 699 not in val tuple
# index 700 not in val tuple
# index 701 not in val tuple
# index 703 not in val tuple
# index 704 not in val tuple
# index 705 not in val tuple
# index 706 not in val tuple
# index 707 not in val tuple
# index 708 not in val tuple
# index 709 not in val tuple
# index 712 not in val tuple
# index 713 not in val tuple
# index 714 not in val tuple
# index 716 not in val tuple
# index 718 not in val tuple
# index 719 not in val tuple
# index 720 not in val tuple
# index 721 not in val tuple
# index 722 not in val tuple
# index 723 not in val tuple
# index 724 not in val tuple
# index 725 not in val tuple
# index 726 not in val tuple
# index 727 not in val tuple
# index 728 not in val tuple
# index 729 not in val tuple
# index 730 not in val tuple
# index 731 not in val tuple
# index 732 not in val tuple
# index 734 not in val tuple
# index 735 not in val tuple
# index 736 not in val tuple
# index 737 not in val tuple
# index 738 not in val tuple
# index 739 not in val tuple
# index 740 not in val tuple
# index 741 not in val tuple
# index 744 not in val tuple
# index 745 not in val tuple
# index 746 not in val tuple
# index 747 not in val tuple
# index 748 not in val tuple
# index 749 not in val tuple
# index 750 not in val tuple
# index 751 not in val tuple
# index 752 not in val tuple
# index 753 not in val tuple
# index 754 not in val tuple
# index 755 not in val tuple
# index 756 not in val tuple
# index 757 not in val tuple
# index 758 not in val tuple
# index 759 not in val tuple
# index 760 not in val tuple
# index 762 not in val tuple
# index 763 not in val tuple
# index 764 not in val tuple
# index 765 not in val tuple
# index 766 not in val tuple
# index 767 not in val tuple
# index 768 not in val tuple
# index 769 not in val tuple
# index 770 not in val tuple
# index 771 not in val tuple
# index 772 not in val tuple
# index 773 not in val tuple
# index 774 not in val tuple
# index 775 not in val tuple
# index 776 not in val tuple
# index 777 not in val tuple
# index 778 not in val tuple
# index 779 not in val tuple
# index 780 not in val tuple
# index 781 not in val tuple
# index 782 not in val tuple
# index 783 not in val tuple
# index 784 not in val tuple
# index 785 not in val tuple
# index 786 not in val tuple
# index 787 not in val tuple
# index 788 not in val tuple
# index 789 not in val tuple
# index 790 not in val tuple
# index 792 not in val tuple
# index 793 not in val tuple
# index 794 not in val tuple
# index 795 not in val tuple
# index 796 not in val tuple
# index 797 not in val tuple
# index 798 not in val tuple
# index 799 not in val tuple
# index 800 not in val tuple
# index 801 not in val tuple
# index 802 not in val tuple
# index 803 not in val tuple
# index 804 not in val tuple
# index 805 not in val tuple
# index 806 not in val tuple
# index 807 not in val tuple
# index 808 not in val tuple
# index 809 not in val tuple
# index 810 not in val tuple
# index 811 not in val tuple
# index 812 not in val tuple
# index 813 not in val tuple
# index 814 not in val tuple
# index 815 not in val tuple
# index 817 not in val tuple
# index 818 not in val tuple
# index 819 not in val tuple
# index 820 not in val tuple
# index 821 not in val tuple
# index 822 not in val tuple
# index 823 not in val tuple
# index 825 not in val tuple
# index 827 not in val tuple
# index 828 not in val tuple
# index 829 not in val tuple
# index 830 not in val tuple
# index 831 not in val tuple
# index 832 not in val tuple
# index 833 not in val tuple
# index 834 not in val tuple
# index 837 not in val tuple
# index 838 not in val tuple
# index 839 not in val tuple
# index 840 not in val tuple
# index 841 not in val tuple
# index 842 not in val tuple
# index 843 not in val tuple
# index 844 not in val tuple
# index 846 not in val tuple
# index 847 not in val tuple
# index 848 not in val tuple
# index 849 not in val tuple
# index 850 not in val tuple
# index 851 not in val tuple
# index 854 not in val tuple
# index 856 not in val tuple
# index 857 not in val tuple
# index 858 not in val tuple
# index 859 not in val tuple
# index 860 not in val tuple
# index 861 not in val tuple
# index 862 not in val tuple
# index 863 not in val tuple
# index 864 not in val tuple
# index 865 not in val tuple
# index 866 not in val tuple
# index 867 not in val tuple
# index 868 not in val tuple
# index 869 not in val tuple
# index 870 not in val tuple
# index 872 not in val tuple
# index 873 not in val tuple
# index 874 not in val tuple
# index 875 not in val tuple
# index 876 not in val tuple
# index 877 not in val tuple
# index 878 not in val tuple
# index 879 not in val tuple
# index 881 not in val tuple
# index 882 not in val tuple
# index 883 not in val tuple
# index 885 not in val tuple
# index 886 not in val tuple
# index 887 not in val tuple
# index 888 not in val tuple
# index 889 not in val tuple
# index 890 not in val tuple
# index 891 not in val tuple
# index 892 not in val tuple
# index 893 not in val tuple
# index 895 not in val tuple
# index 896 not in val tuple
# index 898 not in val tuple
# index 899 not in val tuple
# index 900 not in val tuple
# index 901 not in val tuple
# index 902 not in val tuple
# index 903 not in val tuple
# index 905 not in val tuple
# index 906 not in val tuple
# index 907 not in val tuple
# index 908 not in val tuple
# index 909 not in val tuple
# index 910 not in val tuple
# index 912 not in val tuple
# index 913 not in val tuple
# index 914 not in val tuple
# index 915 not in val tuple
# index 917 not in val tuple
# index 918 not in val tuple
# index 919 not in val tuple
# index 921 not in val tuple
# index 922 not in val tuple
# index 924 not in val tuple
# index 925 not in val tuple
# index 926 not in val tuple
# index 927 not in val tuple
# index 928 not in val tuple
# index 930 not in val tuple
# index 931 not in val tuple
# index 932 not in val tuple
# index 933 not in val tuple
# index 934 not in val tuple
# index 935 not in val tuple
# index 936 not in val tuple
# index 937 not in val tuple
# index 938 not in val tuple
# index 939 not in val tuple
# index 940 not in val tuple
# index 941 not in val tuple
# index 942 not in val tuple
# index 944 not in val tuple
# index 945 not in val tuple
# index 946 not in val tuple
# index 947 not in val tuple
# index 948 not in val tuple
# index 950 not in val tuple
# index 951 not in val tuple
# index 952 not in val tuple
# index 954 not in val tuple
# index 955 not in val tuple
# index 956 not in val tuple
# index 957 not in val tuple
# index 958 not in val tuple
# index 959 not in val tuple
# index 961 not in val tuple
# index 962 not in val tuple
# index 963 not in val tuple
# index 964 not in val tuple
# index 965 not in val tuple
# index 966 not in val tuple
# index 967 not in val tuple
# index 969 not in val tuple
# index 970 not in val tuple
# index 971 not in val tuple
# index 972 not in val tuple
# index 973 not in val tuple
# index 974 not in val tuple
# index 975 not in val tuple
# index 976 not in val tuple
# index 977 not in val tuple
# index 979 not in val tuple
# index 980 not in val tuple
# index 981 not in val tuple
# index 982 not in val tuple
# index 983 not in val tuple
# index 984 not in val tuple
# index 985 not in val tuple
# index 986 not in val tuple
# index 988 not in val tuple
# index 989 not in val tuple
# index 990 not in val tuple
# index 991 not in val tuple
# index 992 not in val tuple
# index 994 not in val tuple
# index 995 not in val tuple
# index 997 not in val tuple
# index 998 not in val tuple
# index 999 not in val tuple
# index 1000 not in val tuple
# index 1001 not in val tuple
# index 1002 not in val tuple
# index 1003 not in val tuple
# index 1004 not in val tuple
# index 1005 not in val tuple
# index 1006 not in val tuple
# index 1007 not in val tuple
# index 1008 not in val tuple
# index 1009 not in val tuple
# index 1011 not in val tuple
# index 1012 not in val tuple
# index 1013 not in val tuple
# index 1014 not in val tuple
# index 1015 not in val tuple
# index 1016 not in val tuple
# index 1017 not in val tuple
# index 1019 not in val tuple
# index 1020 not in val tuple
# index 1022 not in val tuple
# index 1023 not in val tuple
# index 1024 not in val tuple
# index 1025 not in val tuple
# index 1026 not in val tuple
# index 1028 not in val tuple
# index 1030 not in val tuple
# index 1031 not in val tuple
# index 1032 not in val tuple
# index 1034 not in val tuple
# index 1035 not in val tuple
# index 1036 not in val tuple
# index 1037 not in val tuple
# index 1038 not in val tuple
# index 1039 not in val tuple
# index 1040 not in val tuple
# index 1041 not in val tuple
# index 1042 not in val tuple
# index 1043 not in val tuple
# index 1044 not in val tuple
# index 1045 not in val tuple
# index 1046 not in val tuple
# index 1047 not in val tuple
# index 1048 not in val tuple
# index 1050 not in val tuple
# index 1051 not in val tuple
# index 1052 not in val tuple
# index 1053 not in val tuple
# index 1054 not in val tuple
# index 1055 not in val tuple
# index 1057 not in val tuple
# index 1058 not in val tuple
# index 1059 not in val tuple
# index 1060 not in val tuple
# index 1062 not in val tuple
# index 1065 not in val tuple
# index 1067 not in val tuple
# index 1068 not in val tuple
# index 1069 not in val tuple
# index 1071 not in val tuple
# index 1072 not in val tuple
# index 1073 not in val tuple
# index 1074 not in val tuple
# index 1076 not in val tuple
# index 1077 not in val tuple
# index 1078 not in val tuple
# index 1079 not in val tuple
# index 1080 not in val tuple
# index 1081 not in val tuple
# index 1082 not in val tuple
# index 1083 not in val tuple
# index 1085 not in val tuple
# index 1086 not in val tuple
# index 1087 not in val tuple
# index 1088 not in val tuple
# index 1090 not in val tuple
# index 1091 not in val tuple
# index 1092 not in val tuple
# index 1093 not in val tuple
# index 1094 not in val tuple
# index 1095 not in val tuple
# index 1096 not in val tuple
# index 1097 not in val tuple
# index 1098 not in val tuple
# index 1099 not in val tuple
# index 1100 not in val tuple
# index 1101 not in val tuple
# index 1102 not in val tuple
# index 1103 not in val tuple
# index 1105 not in val tuple
# index 1107 not in val tuple
# index 1108 not in val tuple
# index 1109 not in val tuple
# index 1112 not in val tuple
# index 1114 not in val tuple
# index 1115 not in val tuple
# index 1116 not in val tuple
# index 1117 not in val tuple
# index 1118 not in val tuple
# index 1119 not in val tuple
# index 1120 not in val tuple
# index 1121 not in val tuple
# index 1122 not in val tuple
# index 1123 not in val tuple
# index 1124 not in val tuple
# index 1125 not in val tuple
# index 1126 not in val tuple
# index 1127 not in val tuple
# index 1128 not in val tuple
# index 1129 not in val tuple
# index 1130 not in val tuple
# index 1131 not in val tuple
# index 1132 not in val tuple
# index 1133 not in val tuple
# index 1134 not in val tuple
# index 1135 not in val tuple
# index 1136 not in val tuple
# index 1138 not in val tuple
# index 1139 not in val tuple
# index 1140 not in val tuple
# index 1141 not in val tuple
# index 1142 not in val tuple
# index 1143 not in val tuple
# index 1144 not in val tuple
# index 1145 not in val tuple
# index 1146 not in val tuple
# index 1147 not in val tuple
# index 1150 not in val tuple
# index 1151 not in val tuple
# index 1152 not in val tuple
# index 1153 not in val tuple
# index 1154 not in val tuple
# index 1155 not in val tuple
# index 1156 not in val tuple
# index 1157 not in val tuple
# index 1158 not in val tuple
# index 1159 not in val tuple
# index 1160 not in val tuple
# index 1161 not in val tuple
# index 1162 not in val tuple
# index 1163 not in val tuple
# index 1164 not in val tuple
# index 1166 not in val tuple
# index 1167 not in val tuple
# index 1168 not in val tuple
# index 1169 not in val tuple
# index 1171 not in val tuple
# index 1172 not in val tuple
# index 1173 not in val tuple
# index 1174 not in val tuple
# index 1175 not in val tuple
# index 1176 not in val tuple
# index 1177 not in val tuple
# index 1178 not in val tuple
# index 1179 not in val tuple
# index 1180 not in val tuple
# index 1181 not in val tuple
# index 1182 not in val tuple
# index 1183 not in val tuple
# index 1184 not in val tuple
# index 1185 not in val tuple
# index 1186 not in val tuple
# index 1187 not in val tuple
# index 1189 not in val tuple
# index 1191 not in val tuple
# index 1192 not in val tuple
# index 1193 not in val tuple
# index 1194 not in val tuple
# index 1195 not in val tuple
# index 1196 not in val tuple
# index 1197 not in val tuple
# index 1198 not in val tuple
# index 1199 not in val tuple
# index 1200 not in val tuple
# index 1201 not in val tuple
# index 1202 not in val tuple
# index 1203 not in val tuple
# index 1205 not in val tuple
# index 1206 not in val tuple
# index 1207 not in val tuple
# index 1208 not in val tuple
# index 1209 not in val tuple
# index 1211 not in val tuple
# index 1212 not in val tuple
# index 1213 not in val tuple
# index 1214 not in val tuple
# index 1215 not in val tuple
# index 1216 not in val tuple
# index 1217 not in val tuple
# index 1218 not in val tuple
# index 1219 not in val tuple
# index 1220 not in val tuple
# index 1221 not in val tuple
# index 1223 not in val tuple
# index 1224 not in val tuple
# index 1225 not in val tuple
# index 1226 not in val tuple
# index 1227 not in val tuple
# index 1228 not in val tuple
# index 1229 not in val tuple
# index 1230 not in val tuple
# index 1231 not in val tuple
# index 1232 not in val tuple
# index 1233 not in val tuple
# index 1234 not in val tuple
# index 1235 not in val tuple
# index 1236 not in val tuple
# index 1237 not in val tuple
# index 1238 not in val tuple
# index 1240 not in val tuple
# index 1241 not in val tuple
# index 1242 not in val tuple
# index 1243 not in val tuple
# index 1244 not in val tuple
# index 1245 not in val tuple
# index 1246 not in val tuple
# index 1247 not in val tuple
# index 1249 not in val tuple
# index 1251 not in val tuple
# index 1252 not in val tuple
# index 1255 not in val tuple
# index 1256 not in val tuple
# index 1257 not in val tuple
# index 1258 not in val tuple
# index 1259 not in val tuple
# index 1260 not in val tuple
# index 1261 not in val tuple
# index 1262 not in val tuple
# index 1263 not in val tuple
# index 1264 not in val tuple
# index 1265 not in val tuple
# index 1266 not in val tuple
# index 1267 not in val tuple
# index 1268 not in val tuple
# index 1269 not in val tuple
# index 1270 not in val tuple
# index 1271 not in val tuple
# index 1272 not in val tuple
# index 1273 not in val tuple
# index 1275 not in val tuple
# index 1276 not in val tuple
# index 1277 not in val tuple
# index 1278 not in val tuple
# index 1279 not in val tuple
# index 1280 not in val tuple
# index 1281 not in val tuple
# index 1283 not in val tuple
# index 1284 not in val tuple
# index 1285 not in val tuple
# index 1286 not in val tuple
# index 1287 not in val tuple
# index 1288 not in val tuple
# index 1289 not in val tuple
# index 1290 not in val tuple
# index 1292 not in val tuple
# index 1293 not in val tuple
# index 1294 not in val tuple
# index 1295 not in val tuple
# index 1297 not in val tuple
# index 1298 not in val tuple
# index 1299 not in val tuple
# index 1300 not in val tuple
# index 1301 not in val tuple
# index 1302 not in val tuple
# index 1303 not in val tuple
# index 1305 not in val tuple
# index 1306 not in val tuple
# index 1307 not in val tuple
# index 1308 not in val tuple
# index 1309 not in val tuple
# index 1310 not in val tuple
# index 1311 not in val tuple
# index 1312 not in val tuple
# index 1313 not in val tuple
# index 1314 not in val tuple
# index 1315 not in val tuple
# index 1316 not in val tuple
# index 1317 not in val tuple
# index 1319 not in val tuple
# index 1320 not in val tuple
# index 1321 not in val tuple
# index 1322 not in val tuple
# index 1323 not in val tuple
# index 1324 not in val tuple
# index 1325 not in val tuple
# index 1326 not in val tuple
# index 1327 not in val tuple
# index 1328 not in val tuple
# index 1329 not in val tuple
# index 1331 not in val tuple
# index 1332 not in val tuple
# index 1333 not in val tuple
# index 1334 not in val tuple
# index 1335 not in val tuple
# index 1337 not in val tuple
# index 1338 not in val tuple
# index 1339 not in val tuple
# index 1340 not in val tuple
# index 1341 not in val tuple
# index 1342 not in val tuple
# index 1343 not in val tuple
# index 1344 not in val tuple
# index 1345 not in val tuple
# index 1347 not in val tuple
# index 1348 not in val tuple
# index 1349 not in val tuple
# index 1350 not in val tuple
# index 1351 not in val tuple
# index 1352 not in val tuple
# index 1353 not in val tuple
# index 1354 not in val tuple
# index 1355 not in val tuple
# index 1357 not in val tuple
# index 1358 not in val tuple
# index 1359 not in val tuple
# index 1360 not in val tuple
# index 1361 not in val tuple
# index 1362 not in val tuple
# index 1363 not in val tuple
# index 1364 not in val tuple
# index 1365 not in val tuple
# index 1367 not in val tuple
# index 1368 not in val tuple
# index 1369 not in val tuple
# index 1370 not in val tuple
# index 1371 not in val tuple
# index 1372 not in val tuple
# index 1373 not in val tuple
# index 1374 not in val tuple
# index 1375 not in val tuple
# index 1376 not in val tuple
# index 1377 not in val tuple
# index 1378 not in val tuple
# index 1379 not in val tuple
# index 1380 not in val tuple
# index 1381 not in val tuple
# index 1382 not in val tuple
# index 1383 not in val tuple
# index 1384 not in val tuple
# index 1385 not in val tuple
# index 1386 not in val tuple
# index 1387 not in val tuple
# index 1389 not in val tuple
# index 1390 not in val tuple
# index 1391 not in val tuple
# index 1393 not in val tuple
# index 1394 not in val tuple
# index 1395 not in val tuple
# index 1396 not in val tuple
# index 1398 not in val tuple
# index 1399 not in val tuple
# index 1400 not in val tuple
# index 1401 not in val tuple
# index 1402 not in val tuple
# index 1405 not in val tuple
# index 1406 not in val tuple
# index 1407 not in val tuple
# index 1408 not in val tuple
# index 1409 not in val tuple
# index 1410 not in val tuple
# index 1412 not in val tuple
# index 1413 not in val tuple
# index 1414 not in val tuple
# index 1416 not in val tuple
# index 1417 not in val tuple
# index 1418 not in val tuple
# index 1419 not in val tuple
# index 1421 not in val tuple
# index 1422 not in val tuple
# index 1423 not in val tuple
# index 1424 not in val tuple
# index 1425 not in val tuple
# index 1428 not in val tuple
# index 1430 not in val tuple
# index 1432 not in val tuple
# index 1433 not in val tuple
# index 1434 not in val tuple
# index 1435 not in val tuple
# index 1436 not in val tuple
# index 1437 not in val tuple
# index 1439 not in val tuple
# index 1440 not in val tuple
# index 1441 not in val tuple
# index 1442 not in val tuple
# index 1443 not in val tuple
# index 1444 not in val tuple
# index 1445 not in val tuple
# index 1446 not in val tuple
# index 1447 not in val tuple
# index 1448 not in val tuple
# index 1449 not in val tuple
# index 1450 not in val tuple
# index 1451 not in val tuple
# index 1452 not in val tuple
# index 1454 not in val tuple
# index 1455 not in val tuple
# index 1456 not in val tuple
# index 1458 not in val tuple
# index 1459 not in val tuple
# index 1461 not in val tuple
# index 1462 not in val tuple
# index 1463 not in val tuple
# index 1464 not in val tuple
# index 1465 not in val tuple
# index 1466 not in val tuple
# index 1467 not in val tuple
# index 1468 not in val tuple
# index 1469 not in val tuple
# index 1470 not in val tuple
# index 1471 not in val tuple
# index 1472 not in val tuple
# index 1473 not in val tuple
# index 1474 not in val tuple
# index 1475 not in val tuple
# index 1476 not in val tuple
# index 1477 not in val tuple
# index 1478 not in val tuple
# index 1479 not in val tuple
# index 1482 not in val tuple
# index 1484 not in val tuple
# index 1485 not in val tuple
# index 1488 not in val tuple
# index 1489 not in val tuple
# index 1491 not in val tuple
# index 1492 not in val tuple
# index 1493 not in val tuple
# index 1494 not in val tuple
# index 1495 not in val tuple
# index 1496 not in val tuple
# index 1497 not in val tuple
# index 1498 not in val tuple
# index 1499 not in val tuple
# index 1500 not in val tuple
# index 1502 not in val tuple
# index 1503 not in val tuple
# index 1504 not in val tuple
# index 1506 not in val tuple
# index 1507 not in val tuple
# index 1508 not in val tuple
# index 1509 not in val tuple
# index 1510 not in val tuple
# index 1511 not in val tuple
# index 1512 not in val tuple
# index 1513 not in val tuple
# index 1514 not in val tuple
# index 1515 not in val tuple
# index 1516 not in val tuple
# index 1517 not in val tuple
# index 1518 not in val tuple
# index 1519 not in val tuple
# index 1520 not in val tuple
# index 1521 not in val tuple
# index 1522 not in val tuple
# index 1523 not in val tuple
# index 1526 not in val tuple
# index 1528 not in val tuple
# index 1529 not in val tuple
# index 1530 not in val tuple
# index 1531 not in val tuple
# index 1532 not in val tuple
# index 1533 not in val tuple
# index 1534 not in val tuple
# index 1535 not in val tuple
# index 1536 not in val tuple
# index 1537 not in val tuple
# index 1538 not in val tuple
# index 1539 not in val tuple
# index 1540 not in val tuple
# index 1541 not in val tuple
# index 1542 not in val tuple
# index 1543 not in val tuple
# index 1544 not in val tuple
# index 1545 not in val tuple
# index 1546 not in val tuple
# index 1547 not in val tuple
# index 1548 not in val tuple
# index 1549 not in val tuple
# index 1550 not in val tuple
# index 1551 not in val tuple
# index 1552 not in val tuple
# index 1554 not in val tuple
# index 1555 not in val tuple
# index 1556 not in val tuple
# index 1557 not in val tuple
# index 1558 not in val tuple
# index 1560 not in val tuple
# index 1561 not in val tuple
# index 1562 not in val tuple
# index 1564 not in val tuple
# index 1565 not in val tuple
# index 1566 not in val tuple
# index 1567 not in val tuple
# index 1568 not in val tuple
# index 1569 not in val tuple
# index 1570 not in val tuple
# index 1571 not in val tuple
# index 1572 not in val tuple
# index 1573 not in val tuple
# index 1574 not in val tuple
# index 1576 not in val tuple
# index 1577 not in val tuple
# index 1578 not in val tuple
# index 1579 not in val tuple
# index 1580 not in val tuple
# index 1581 not in val tuple
# index 1583 not in val tuple
# index 1584 not in val tuple
# index 1585 not in val tuple
# index 1586 not in val tuple
# index 1587 not in val tuple
# index 1589 not in val tuple
# index 1591 not in val tuple
# index 1592 not in val tuple
# index 1594 not in val tuple
# index 1595 not in val tuple
# index 1596 not in val tuple
# index 1597 not in val tuple
# index 1598 not in val tuple
# index 1600 not in val tuple
# index 1602 not in val tuple
# index 1604 not in val tuple
# index 1605 not in val tuple
# index 1606 not in val tuple
# index 1608 not in val tuple
# index 1609 not in val tuple
# index 1610 not in val tuple
# index 1611 not in val tuple
# index 1612 not in val tuple
# index 1613 not in val tuple
# index 1614 not in val tuple
# index 1617 not in val tuple
# index 1618 not in val tuple
# index 1619 not in val tuple
# index 1620 not in val tuple
# index 1621 not in val tuple
# index 1622 not in val tuple
# index 1623 not in val tuple
# index 1624 not in val tuple
# index 1625 not in val tuple
# index 1626 not in val tuple
# index 1627 not in val tuple
# index 1629 not in val tuple
# index 1630 not in val tuple
# index 1631 not in val tuple
# index 1632 not in val tuple
# index 1633 not in val tuple
# index 1634 not in val tuple
# index 1635 not in val tuple
# index 1637 not in val tuple
# index 1638 not in val tuple
# index 1640 not in val tuple
# index 1641 not in val tuple
# index 1642 not in val tuple
# index 1644 not in val tuple
# index 1645 not in val tuple
# index 1646 not in val tuple
# index 1647 not in val tuple
# index 1648 not in val tuple
# index 1649 not in val tuple
# index 1650 not in val tuple
# index 1651 not in val tuple
# index 1652 not in val tuple
# index 1653 not in val tuple
# index 1654 not in val tuple
# index 1655 not in val tuple
# index 1656 not in val tuple
# index 1657 not in val tuple
# index 1658 not in val tuple
# index 1659 not in val tuple
# index 1660 not in val tuple
# index 1661 not in val tuple
# index 1662 not in val tuple
# index 1663 not in val tuple
# index 1666 not in val tuple
# index 1667 not in val tuple
# index 1668 not in val tuple
# index 1669 not in val tuple
# index 1671 not in val tuple
# index 1672 not in val tuple
# index 1674 not in val tuple
# index 1675 not in val tuple
# index 1676 not in val tuple
# index 1677 not in val tuple
# index 1679 not in val tuple
# index 1680 not in val tuple
# index 1681 not in val tuple
# index 1686 not in val tuple
# index 1687 not in val tuple
# index 1688 not in val tuple
# index 1690 not in val tuple
# index 1691 not in val tuple
# index 1692 not in val tuple
# index 1693 not in val tuple
# index 1694 not in val tuple
# index 1695 not in val tuple
# index 1696 not in val tuple
# index 1697 not in val tuple
# index 1698 not in val tuple
# index 1699 not in val tuple
# index 1700 not in val tuple
# index 1701 not in val tuple
# index 1702 not in val tuple
# index 1703 not in val tuple
# index 1704 not in val tuple
# index 1705 not in val tuple
# index 1706 not in val tuple
# index 1707 not in val tuple
# index 1708 not in val tuple
# index 1709 not in val tuple
# index 1710 not in val tuple
# index 1711 not in val tuple
# index 1712 not in val tuple
# index 1713 not in val tuple
# index 1715 not in val tuple
# index 1716 not in val tuple
# index 1717 not in val tuple
# index 1718 not in val tuple
# index 1719 not in val tuple
# index 1720 not in val tuple
# index 1721 not in val tuple
# index 1722 not in val tuple
# index 1724 not in val tuple
# index 1725 not in val tuple
# index 1726 not in val tuple
# index 1729 not in val tuple
# index 1730 not in val tuple
# index 1731 not in val tuple
# index 1732 not in val tuple
# index 1733 not in val tuple
# index 1734 not in val tuple
# index 1735 not in val tuple
# index 1737 not in val tuple
# index 1738 not in val tuple
# index 1739 not in val tuple
# index 1740 not in val tuple
# index 1741 not in val tuple
# index 1742 not in val tuple
# index 1743 not in val tuple
# index 1745 not in val tuple
# index 1746 not in val tuple
# index 1747 not in val tuple
# index 1748 not in val tuple
# index 1749 not in val tuple
# index 1750 not in val tuple
# index 1751 not in val tuple
# index 1752 not in val tuple
# index 1753 not in val tuple
# index 1754 not in val tuple
# index 1756 not in val tuple
# index 1757 not in val tuple
# index 1758 not in val tuple
# index 1759 not in val tuple
# index 1760 not in val tuple
# index 1761 not in val tuple
# index 1762 not in val tuple
# index 1763 not in val tuple
# index 1764 not in val tuple
# index 1765 not in val tuple
# index 1766 not in val tuple
# index 1767 not in val tuple
# index 1768 not in val tuple
# index 1769 not in val tuple
# index 1770 not in val tuple
# index 1771 not in val tuple
# index 1774 not in val tuple
# index 1775 not in val tuple
# index 1776 not in val tuple
# index 1777 not in val tuple
# index 1778 not in val tuple
# index 1779 not in val tuple
# index 1781 not in val tuple
# index 1782 not in val tuple
# index 1783 not in val tuple
# index 1784 not in val tuple
# index 1785 not in val tuple
# index 1786 not in val tuple
# index 1787 not in val tuple
# index 1788 not in val tuple
# index 1789 not in val tuple
# index 1790 not in val tuple
# index 1791 not in val tuple
# index 1793 not in val tuple
# index 1794 not in val tuple
# index 1795 not in val tuple
# index 1796 not in val tuple
# index 1797 not in val tuple
# index 1798 not in val tuple
# index 1799 not in val tuple
# index 1800 not in val tuple
# index 1801 not in val tuple
# index 1802 not in val tuple
# index 1804 not in val tuple
# index 1805 not in val tuple
# index 1806 not in val tuple
# index 1807 not in val tuple
# index 1808 not in val tuple
# index 1810 not in val tuple
# index 1812 not in val tuple
# index 1813 not in val tuple
# index 1815 not in val tuple
# index 1816 not in val tuple
# index 1818 not in val tuple
# index 1819 not in val tuple
# index 1820 not in val tuple
# index 1821 not in val tuple
# index 1822 not in val tuple
# index 1823 not in val tuple
# index 1824 not in val tuple
# index 1825 not in val tuple
# index 1826 not in val tuple
# index 1827 not in val tuple
# index 1828 not in val tuple
# index 1829 not in val tuple
# index 1830 not in val tuple
# index 1832 not in val tuple
# index 1833 not in val tuple
# index 1834 not in val tuple
# index 1835 not in val tuple
# index 1836 not in val tuple
# index 1837 not in val tuple
# index 1838 not in val tuple
# index 1839 not in val tuple
# index 1840 not in val tuple
# index 1842 not in val tuple
# index 1843 not in val tuple
# index 1844 not in val tuple
# index 1845 not in val tuple
# index 1846 not in val tuple
# index 1847 not in val tuple
# index 1848 not in val tuple
# index 1849 not in val tuple
# index 1850 not in val tuple
# index 1851 not in val tuple
# index 1852 not in val tuple
# index 1853 not in val tuple
# index 1855 not in val tuple
# index 1856 not in val tuple
# index 1857 not in val tuple
# index 1858 not in val tuple
# index 1859 not in val tuple
# index 1860 not in val tuple
# index 1861 not in val tuple
# index 1862 not in val tuple
# index 1863 not in val tuple
# index 1864 not in val tuple
# index 1865 not in val tuple
# index 1866 not in val tuple
# index 1867 not in val tuple
# index 1868 not in val tuple
# index 1870 not in val tuple
# index 1871 not in val tuple
# index 1873 not in val tuple
# index 1874 not in val tuple
# index 1875 not in val tuple
# index 1876 not in val tuple
# index 1877 not in val tuple
# index 1878 not in val tuple
# index 1879 not in val tuple
# index 1880 not in val tuple
# index 1881 not in val tuple
# index 1882 not in val tuple
# index 1883 not in val tuple
# index 1884 not in val tuple
# index 1885 not in val tuple
# index 1886 not in val tuple
# index 1887 not in val tuple
# index 1888 not in val tuple
# index 1889 not in val tuple
# index 1890 not in val tuple
# index 1891 not in val tuple
# index 1892 not in val tuple
# index 1893 not in val tuple
# index 1894 not in val tuple
# index 1895 not in val tuple
# index 1896 not in val tuple
# index 1897 not in val tuple
# index 1898 not in val tuple
# index 1900 not in val tuple
# index 1901 not in val tuple
# index 1902 not in val tuple
# index 1903 not in val tuple
# index 1904 not in val tuple
# index 1905 not in val tuple
# index 1906 not in val tuple
# index 1907 not in val tuple
# index 1908 not in val tuple
# index 1909 not in val tuple
# index 1910 not in val tuple
# index 1911 not in val tuple
# index 1912 not in val tuple
# index 1913 not in val tuple
# index 1914 not in val tuple
# index 1915 not in val tuple
# index 1916 not in val tuple
# index 1917 not in val tuple
# index 1918 not in val tuple
# index 1920 not in val tuple
# index 1921 not in val tuple
# index 1922 not in val tuple
# index 1923 not in val tuple
# index 1924 not in val tuple
# index 1925 not in val tuple
# index 1927 not in val tuple
# index 1928 not in val tuple
# index 1929 not in val tuple
# index 1930 not in val tuple
# index 1931 not in val tuple
# index 1932 not in val tuple
# index 1933 not in val tuple
# index 1934 not in val tuple
# index 1935 not in val tuple
# index 1936 not in val tuple
# index 1937 not in val tuple
# index 1938 not in val tuple
# index 1939 not in val tuple
# index 1940 not in val tuple
# index 1941 not in val tuple
# index 1942 not in val tuple
# index 1943 not in val tuple
# index 1944 not in val tuple
# index 1945 not in val tuple
# index 1947 not in val tuple
# index 1948 not in val tuple
# index 1952 not in val tuple
# index 1953 not in val tuple
# index 1954 not in val tuple
# index 1955 not in val tuple
# index 1956 not in val tuple
# index 1957 not in val tuple
# index 1958 not in val tuple
# index 1959 not in val tuple
# index 1960 not in val tuple
# index 1961 not in val tuple
# index 1962 not in val tuple
# index 1963 not in val tuple
# index 1964 not in val tuple
# index 1965 not in val tuple
# index 1966 not in val tuple
# index 1967 not in val tuple
# index 1968 not in val tuple
# index 1969 not in val tuple
# index 1970 not in val tuple
# index 1971 not in val tuple
# index 1972 not in val tuple
# index 1973 not in val tuple
# index 1974 not in val tuple
# index 1975 not in val tuple
# index 1976 not in val tuple
# index 1977 not in val tuple
# index 1978 not in val tuple
# index 1979 not in val tuple
# index 1980 not in val tuple
# index 1981 not in val tuple
# index 1982 not in val tuple
# index 1983 not in val tuple
# index 1984 not in val tuple
# index 1985 not in val tuple
# index 1986 not in val tuple
# index 1987 not in val tuple
# index 1988 not in val tuple
# index 1990 not in val tuple
# index 1991 not in val tuple
# ...
# index 2648 not in val tuple
# index 2649 not in val tuple
# index 2650 not in val tuple
# index 2651 not in val tuple
# index 2652 not in val tuple
# index 2653 not in val tuple
# index 2654 not in val tuple
# index 2657 not in val tuple
# index 2658 not in val tuple
# index 2659 not in val tuple
# index 2660 not in val tuple
# index 2661 not in val tuple
# index 2662 not in val tuple
# index 2663 not in val tuple
# index 2664 not in val tuple
# index 2666 not in val tuple
# index 2667 not in val tuple
# index 2668 not in val tuple
# index 2669 not in val tuple
# index 2670 not in val tuple
# index 2671 not in val tuple
# index 2672 not in val tuple
# index 2673 not in val tuple
# index 2674 not in val tuple
# index 2675 not in val tuple
# index 2676 not in val tuple
# index 2677 not in val tuple
# index 2678 not in val tuple
# index 2679 not in val tuple
# index 2681 not in val tuple
# index 2682 not in val tuple
# index 2683 not in val tuple
# index 2684 not in val tuple
# index 2685 not in val tuple
# index 2686 not in val tuple
# index 2688 not in val tuple
# index 2689 not in val tuple
# index 2690 not in val tuple
# index 2691 not in val tuple
# index 2692 not in val tuple
# index 2693 not in val tuple
# index 2694 not in val tuple
# index 2695 not in val tuple
# index 2696 not in val tuple
# index 2697 not in val tuple
# index 2698 not in val tuple
# index 2699 not in val tuple
# index 2700 not in val tuple
# index 2701 not in val tuple
# index 2702 not in val tuple
# index 2703 not in val tuple
# index 2704 not in val tuple
# index 2705 not in val tuple
# index 2707 not in val tuple
# index 2708 not in val tuple
# index 2709 not in val tuple
# index 2710 not in val tuple
# index 2711 not in val tuple
# index 2712 not in val tuple
# index 2713 not in val tuple
# index 2714 not in val tuple
# index 2715 not in val tuple
# index 2716 not in val tuple
# index 2718 not in val tuple
# index 2719 not in val tuple
# index 2720 not in val tuple
# index 2721 not in val tuple
# index 2722 not in val tuple
# index 2723 not in val tuple
# index 2725 not in val tuple
# index 2726 not in val tuple
# index 2728 not in val tuple
# index 2729 not in val tuple
# index 2730 not in val tuple
# index 2731 not in val tuple
# index 2732 not in val tuple
# index 2733 not in val tuple
# index 2734 not in val tuple
# index 2735 not in val tuple
# index 2736 not in val tuple
# index 2737 not in val tuple
# index 2738 not in val tuple
# index 2739 not in val tuple
# index 2740 not in val tuple
# index 2742 not in val tuple
# index 2744 not in val tuple
# index 2745 not in val tuple
# index 2747 not in val tuple
# index 2748 not in val tuple
# index 2749 not in val tuple
# index 2751 not in val tuple
# index 2752 not in val tuple
# index 2753 not in val tuple
# index 2754 not in val tuple
# index 2755 not in val tuple
# index 2756 not in val tuple
# index 2757 not in val tuple
# index 2758 not in val tuple
# index 2761 not in val tuple
# index 2762 not in val tuple
# index 2763 not in val tuple
# index 2764 not in val tuple
# index 2765 not in val tuple
# index 2766 not in val tuple
# index 2767 not in val tuple
# index 2769 not in val tuple
# index 2770 not in val tuple
# index 2771 not in val tuple
# index 2773 not in val tuple
# index 2774 not in val tuple
# index 2775 not in val tuple
# index 2776 not in val tuple
# index 2777 not in val tuple
# index 2778 not in val tuple
# index 2779 not in val tuple
# index 2780 not in val tuple
# index 2781 not in val tuple
# index 2782 not in val tuple
# index 2783 not in val tuple
# index 2784 not in val tuple
# index 2785 not in val tuple
# index 2786 not in val tuple
# index 2787 not in val tuple
# index 2788 not in val tuple
# index 2789 not in val tuple
# index 2790 not in val tuple
# index 2791 not in val tuple
# index 2792 not in val tuple
# index 2793 not in val tuple
# index 2794 not in val tuple
# index 2795 not in val tuple
# index 2797 not in val tuple
# index 2798 not in val tuple
# index 2799 not in val tuple
# index 2800 not in val tuple
# index 2801 not in val tuple
# index 2802 not in val tuple
# index 2803 not in val tuple
# index 2805 not in val tuple
# index 2806 not in val tuple
# index 2807 not in val tuple
# index 2808 not in val tuple
# index 2809 not in val tuple
# index 2810 not in val tuple
# index 2811 not in val tuple
# index 2812 not in val tuple
# index 2813 not in val tuple
# index 2815 not in val tuple
# index 2816 not in val tuple
# index 2817 not in val tuple
# index 2818 not in val tuple
# index 2819 not in val tuple
# index 2820 not in val tuple
# index 2821 not in val tuple
# index 2822 not in val tuple
# index 2823 not in val tuple
# index 2824 not in val tuple
# index 2825 not in val tuple
# index 2826 not in val tuple
# index 2827 not in val tuple
# index 2828 not in val tuple
# index 2829 not in val tuple
# index 2831 not in val tuple
# index 2832 not in val tuple
# index 2833 not in val tuple
# index 2834 not in val tuple
# index 2836 not in val tuple
# index 2837 not in val tuple
# index 2838 not in val tuple
# index 2839 not in val tuple
# index 2840 not in val tuple
# index 2841 not in val tuple
# index 2842 not in val tuple
# index 2843 not in val tuple
# index 2844 not in val tuple
# index 2845 not in val tuple
# index 2846 not in val tuple
# index 2847 not in val tuple
# index 2849 not in val tuple
# index 2850 not in val tuple
# index 2851 not in val tuple
# index 2853 not in val tuple
# index 2854 not in val tuple
# index 2855 not in val tuple
# index 2856 not in val tuple
# index 2857 not in val tuple
# index 2859 not in val tuple
# index 2860 not in val tuple
# index 2861 not in val tuple
# index 2862 not in val tuple
# index 2863 not in val tuple
# index 2864 not in val tuple
# index 2865 not in val tuple
# index 2866 not in val tuple
# index 2867 not in val tuple
# index 2868 not in val tuple
# index 2869 not in val tuple
# index 2870 not in val tuple
# index 2871 not in val tuple
# index 2872 not in val tuple
# index 2874 not in val tuple
# index 2875 not in val tuple
# index 2876 not in val tuple
# index 2877 not in val tuple
# index 2878 not in val tuple
# index 2879 not in val tuple
# index 2881 not in val tuple
# index 2883 not in val tuple
# index 2884 not in val tuple
# index 2885 not in val tuple
# index 2886 not in val tuple
# index 2887 not in val tuple
# index 2888 not in val tuple
# index 2889 not in val tuple
# index 2890 not in val tuple
# index 2891 not in val tuple
# index 2892 not in val tuple
# index 2893 not in val tuple
# index 2894 not in val tuple
# index 2895 not in val tuple
# index 2897 not in val tuple
# index 2899 not in val tuple
# index 2900 not in val tuple
# index 2902 not in val tuple
# index 2903 not in val tuple
# index 2904 not in val tuple
# index 2905 not in val tuple
# index 2906 not in val tuple
# index 2907 not in val tuple
# index 2910 not in val tuple
# index 2911 not in val tuple
# index 2913 not in val tuple
# index 2914 not in val tuple
# index 2915 not in val tuple
# index 2916 not in val tuple
# index 2917 not in val tuple
# index 2918 not in val tuple
# index 2920 not in val tuple
# index 2921 not in val tuple
# index 2922 not in val tuple
# index 2923 not in val tuple
# index 2924 not in val tuple
# index 2925 not in val tuple
# index 2927 not in val tuple
# index 2928 not in val tuple
# index 2929 not in val tuple
# index 2930 not in val tuple
# index 2931 not in val tuple
# index 2932 not in val tuple
# index 2933 not in val tuple
# index 2934 not in val tuple
# index 2935 not in val tuple
# index 2936 not in val tuple
# index 2938 not in val tuple
# index 2939 not in val tuple
# index 2941 not in val tuple
# index 2942 not in val tuple
# index 2943 not in val tuple
# index 2944 not in val tuple
# index 2945 not in val tuple
# index 2946 not in val tuple
# index 2947 not in val tuple
# index 2948 not in val tuple
# index 2949 not in val tuple
# index 2950 not in val tuple
# index 2951 not in val tuple
# index 2952 not in val tuple
# index 2953 not in val tuple
# index 2954 not in val tuple
# index 2955 not in val tuple
# index 2956 not in val tuple
# index 2957 not in val tuple
# index 2958 not in val tuple
# index 2959 not in val tuple
# index 2960 not in val tuple
# index 2961 not in val tuple
# index 2962 not in val tuple
# index 2963 not in val tuple
# index 2964 not in val tuple
# index 2965 not in val tuple
# index 2966 not in val tuple
# index 2967 not in val tuple
# index 2968 not in val tuple
# index 2969 not in val tuple
# index 2970 not in val tuple
# index 2972 not in val tuple
# index 2973 not in val tuple
# index 2974 not in val tuple
# index 2975 not in val tuple
# index 2976 not in val tuple
# index 2977 not in val tuple
# index 2978 not in val tuple
# index 2979 not in val tuple
# index 2981 not in val tuple
# index 2982 not in val tuple
# index 2983 not in val tuple
# index 2984 not in val tuple
# index 2985 not in val tuple
# index 2986 not in val tuple
# index 2988 not in val tuple
# index 2989 not in val tuple
# index 2991 not in val tuple
# index 2992 not in val tuple
# index 2993 not in val tuple
# index 2995 not in val tuple
# index 2996 not in val tuple
# index 2998 not in val tuple
# index 3000 not in val tuple
# index 3001 not in val tuple
# index 3003 not in val tuple
# index 3004 not in val tuple
# index 3005 not in val tuple
# index 3006 not in val tuple
# index 3007 not in val tuple
# index 3008 not in val tuple
# index 3010 not in val tuple
# index 3011 not in val tuple
# index 3012 not in val tuple
# index 3013 not in val tuple
# index 3014 not in val tuple
# index 3015 not in val tuple
# index 3016 not in val tuple
# index 3017 not in val tuple
# index 3018 not in val tuple
# index 3019 not in val tuple
# index 3020 not in val tuple
# index 3021 not in val tuple
# index 3022 not in val tuple
# index 3023 not in val tuple
# index 3024 not in val tuple
# index 3025 not in val tuple
# index 3026 not in val tuple
# index 3027 not in val tuple
# index 3028 not in val tuple
# index 3029 not in val tuple
# index 3031 not in val tuple
# index 3032 not in val tuple
# index 3033 not in val tuple
# index 3034 not in val tuple
# index 3035 not in val tuple
# index 3036 not in val tuple
# index 3037 not in val tuple
# index 3038 not in val tuple
# index 3039 not in val tuple
# index 3040 not in val tuple
# index 3041 not in val tuple
# index 3043 not in val tuple
# index 3044 not in val tuple
# index 3045 not in val tuple
# index 3046 not in val tuple
# index 3047 not in val tuple
# index 3048 not in val tuple
# index 3049 not in val tuple
# index 3051 not in val tuple
# index 3052 not in val tuple
# index 3053 not in val tuple
# index 3054 not in val tuple
# index 3055 not in val tuple
# index 3056 not in val tuple
# index 3057 not in val tuple
# index 3058 not in val tuple
# index 3059 not in val tuple
# index 3060 not in val tuple
# index 3061 not in val tuple
# index 3062 not in val tuple
# index 3063 not in val tuple
# index 3064 not in val tuple
# index 3065 not in val tuple
# index 3066 not in val tuple
# index 3067 not in val tuple
# index 3068 not in val tuple
# index 3069 not in val tuple
# index 3070 not in val tuple
# index 3072 not in val tuple
# index 3073 not in val tuple
# index 3075 not in val tuple
# index 3076 not in val tuple
# index 3077 not in val tuple
# index 3078 not in val tuple
# index 3079 not in val tuple
# index 3080 not in val tuple
# index 3081 not in val tuple
# index 3082 not in val tuple
# index 3083 not in val tuple
# index 3084 not in val tuple
# index 3085 not in val tuple
# index 3086 not in val tuple
# index 3088 not in val tuple
# index 3089 not in val tuple
# index 3090 not in val tuple
# index 3091 not in val tuple
# index 3092 not in val tuple
# index 3093 not in val tuple
# index 3095 not in val tuple
# index 3096 not in val tuple
# index 3097 not in val tuple
# index 3098 not in val tuple
# index 3099 not in val tuple
# index 3100 not in val tuple
# index 3101 not in val tuple
# index 3103 not in val tuple
# index 3104 not in val tuple
# index 3105 not in val tuple
# index 3106 not in val tuple
# index 3107 not in val tuple
# index 3108 not in val tuple
# index 3109 not in val tuple
# index 3110 not in val tuple
# index 3112 not in val tuple
# index 3113 not in val tuple
# index 3114 not in val tuple
# index 3116 not in val tuple
# index 3117 not in val tuple
# index 3119 not in val tuple
# index 3120 not in val tuple
# index 3122 not in val tuple
# index 3123 not in val tuple
# index 3124 not in val tuple
# index 3125 not in val tuple
# index 3126 not in val tuple
# index 3127 not in val tuple
# index 3128 not in val tuple
# index 3129 not in val tuple
# index 3130 not in val tuple
# index 3131 not in val tuple
# index 3132 not in val tuple
# index 3133 not in val tuple
# index 3135 not in val tuple
# index 3136 not in val tuple
# index 3137 not in val tuple
# index 3138 not in val tuple
# index 3139 not in val tuple
# index 3140 not in val tuple
# index 3141 not in val tuple
# index 3142 not in val tuple
# index 3143 not in val tuple
# index 3144 not in val tuple
# index 3145 not in val tuple
# index 3146 not in val tuple
# index 3148 not in val tuple
# index 3149 not in val tuple
# index 3150 not in val tuple
# index 3151 not in val tuple
# index 3152 not in val tuple
# index 3153 not in val tuple
# index 3154 not in val tuple
# index 3156 not in val tuple
# index 3158 not in val tuple
# index 3159 not in val tuple
# index 3160 not in val tuple
# index 3161 not in val tuple
# index 3162 not in val tuple
# index 3164 not in val tuple
# index 3165 not in val tuple
# index 3166 not in val tuple
# index 3167 not in val tuple
# index 3168 not in val tuple
# index 3169 not in val tuple
# index 3170 not in val tuple
# index 3171 not in val tuple
# index 3172 not in val tuple
# index 3173 not in val tuple
# index 3175 not in val tuple
# index 3176 not in val tuple
# index 3177 not in val tuple
# index 3178 not in val tuple
# index 3179 not in val tuple
# index 3180 not in val tuple
# index 3181 not in val tuple
# index 3182 not in val tuple
# index 3183 not in val tuple
# index 3185 not in val tuple
# index 3186 not in val tuple
# index 3188 not in val tuple
# index 3189 not in val tuple
# index 3190 not in val tuple
# index 3192 not in val tuple
# index 3193 not in val tuple
# index 3195 not in val tuple
# index 3196 not in val tuple
# index 3198 not in val tuple
# index 3199 not in val tuple
# index 3200 not in val tuple
# index 3201 not in val tuple
# index 3202 not in val tuple
# index 3203 not in val tuple
# index 3204 not in val tuple
# index 3205 not in val tuple
# index 3206 not in val tuple
# index 3207 not in val tuple
# index 3209 not in val tuple
# index 3210 not in val tuple
# index 3211 not in val tuple
# index 3212 not in val tuple
# index 3213 not in val tuple
# index 3214 not in val tuple
# index 3216 not in val tuple
# index 3218 not in val tuple
# index 3219 not in val tuple
# index 3220 not in val tuple
# index 3221 not in val tuple
# index 3222 not in val tuple
# index 3223 not in val tuple
# index 3224 not in val tuple
# index 3225 not in val tuple
# index 3226 not in val tuple
# index 3227 not in val tuple
# index 3228 not in val tuple
# index 3229 not in val tuple
# index 3231 not in val tuple
# index 3232 not in val tuple
# index 3233 not in val tuple
# index 3234 not in val tuple
# index 3235 not in val tuple
# index 3239 not in val tuple
# index 3240 not in val tuple
# index 3241 not in val tuple
# index 3242 not in val tuple
# index 3243 not in val tuple
# index 3244 not in val tuple
# index 3245 not in val tuple
# index 3247 not in val tuple
# index 3248 not in val tuple
# index 3249 not in val tuple
# index 3250 not in val tuple
# index 3251 not in val tuple
# index 3252 not in val tuple
# index 3253 not in val tuple
# index 3254 not in val tuple
# index 3256 not in val tuple
# index 3257 not in val tuple
# index 3258 not in val tuple
# index 3259 not in val tuple
# index 3261 not in val tuple
# index 3262 not in val tuple
# index 3263 not in val tuple
# index 3264 not in val tuple
# index 3265 not in val tuple
# index 3266 not in val tuple
# index 3267 not in val tuple
# index 3268 not in val tuple
# index 3269 not in val tuple
# index 3270 not in val tuple
# index 3271 not in val tuple
# index 3272 not in val tuple
# index 3273 not in val tuple
# index 3274 not in val tuple
# index 3275 not in val tuple
# index 3276 not in val tuple
# index 3277 not in val tuple
# index 3278 not in val tuple
# index 3279 not in val tuple
# index 3280 not in val tuple
# index 3281 not in val tuple
# index 3282 not in val tuple
# index 3283 not in val tuple
# index 3284 not in val tuple
# index 3285 not in val tuple
# index 3286 not in val tuple
# index 3287 not in val tuple
# index 3288 not in val tuple
# index 3289 not in val tuple
# index 3290 not in val tuple
# index 3291 not in val tuple
# index 3292 not in val tuple
# index 3293 not in val tuple
# index 3294 not in val tuple
# index 3295 not in val tuple
# index 3296 not in val tuple
# index 3298 not in val tuple
# index 3299 not in val tuple
